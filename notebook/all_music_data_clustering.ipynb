# %% [markdown]
# #### Import libraries

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import numpy as np
import random
import pprint

import pickle
from sklearn import datasets # sklearn comes with some toy datasets to practise
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from matplotlib import pyplot
from sklearn.metrics import silhouette_score

# %% [markdown]
# #### Import dataframe

# %%
df = pd.read_csv('all_music_data.csv')
df
# Out:
#       Unnamed: 0                      song_title           artist  \
# 0              0                         Hey Ya!          Outkast
# 1              1                No Woman, No Cry           Fugees
# 2              2                 Can You Feel It     The Jacksons
# 3              3                         Foolish          Ashanti
# 4              4               Arigato Interlude  Ms. Lauryn Hill
# ...          ...                             ...              ...
# 7312        7312                              XO       John Mayer
# 7313        7313               Un-Break My Heart     Toni Braxton
# 7314        7314                     God Is a DJ        Faithless
# 7315        7315  I Wanna Be Adored - Remastered  The Stone Roses
# 7316        7316                       Adore You      Miley Cyrus
#
#                           id  danceability  energy  key  loudness  mode  \
# 0     0JFx4l1JZJ6XtMAtlCMiqF         0.657   0.883    4    -6.778     0
# 1     5bUVHuzQh5mkvMPjUU074i         0.846   0.326    0   -13.909     1
# 2     1XqgxhR3FcJXzFiSG8m6oL         0.892   0.638    6    -7.468     0
# 3     5wXgj9h0Pc36Rcgwf2qd7A         0.620   0.701    0    -5.742     1
# 4     3abz5HTatP9iv5p8Nm5IT0         0.000   0.978   10    -9.615     1
# ...                      ...           ...     ...  ...       ...   ...
# 7312  0hm785gGfLmHvl9YesZcFP         0.431   0.377    2    -9.753     1
# 7313  5CYbKUBECU71XChJBP01KE         0.620   0.417   11    -9.166     0
# 7314  76QhWAnwj7aSgAYPOPNXYN         0.604   0.893   10    -7.480     0
# 7315  5vnMGVPld0mhqVVHMK89y3         0.502   0.860    4    -9.251     0
# 7316  0N3VOIfkk1Ha2UJiVdeo32         0.552   0.579    0    -7.745     1
#
#       speechiness  ...  instrumentalness  liveness  valence    tempo  \
# 0          0.0526  ...          0.000000    0.3060    0.966   79.397
# 1          0.1520  ...          0.000040    0.2800    0.367   88.988
# 2          0.0488  ...          0.000476    0.2020    0.892  125.359
# 3          0.0624  ...          0.000000    0.1470    0.771   90.059
# 4          0.0000  ...          0.002280    0.9510    0.000    0.000
# ...           ...  ...               ...       ...      ...      ...
# 7312       0.0288  ...          0.000000    0.2110    0.353  173.670
# 7313       0.0286  ...          0.000000    0.0984    0.133  109.904
# 7314       0.0453  ...          0.900000    0.1570    0.366  130.555
# 7315       0.0278  ...          0.240000    0.2160    0.559  112.585
# 7316       0.0332  ...          0.000003    0.1910    0.220  119.748
#
#                 type                                   uri  \
# 0     audio_features  spotify:track:0JFx4l1JZJ6XtMAtlCMiqF
# 1     audio_features  spotify:track:5bUVHuzQh5mkvMPjUU074i
# 2     audio_features  spotify:track:1XqgxhR3FcJXzFiSG8m6oL
# 3     audio_features  spotify:track:5wXgj9h0Pc36Rcgwf2qd7A
# 4     audio_features  spotify:track:3abz5HTatP9iv5p8Nm5IT0
# ...              ...                                   ...
# 7312  audio_features  spotify:track:0hm785gGfLmHvl9YesZcFP
# 7313  audio_features  spotify:track:5CYbKUBECU71XChJBP01KE
# 7314  audio_features  spotify:track:76QhWAnwj7aSgAYPOPNXYN
# 7315  audio_features  spotify:track:5vnMGVPld0mhqVVHMK89y3
# 7316  audio_features  spotify:track:0N3VOIfkk1Ha2UJiVdeo32
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/0JFx4l1JZJ6X...
# 1     https://api.spotify.com/v1/tracks/5bUVHuzQh5mk...
# 2     https://api.spotify.com/v1/tracks/1XqgxhR3FcJX...
# 3     https://api.spotify.com/v1/tracks/5wXgj9h0Pc36...
# 4     https://api.spotify.com/v1/tracks/3abz5HTatP9i...
# ...                                                 ...
# 7312  https://api.spotify.com/v1/tracks/0hm785gGfLmH...
# 7313  https://api.spotify.com/v1/tracks/5CYbKUBECU71...
# 7314  https://api.spotify.com/v1/tracks/76QhWAnwj7aS...
# 7315  https://api.spotify.com/v1/tracks/5vnMGVPld0mh...
# 7316  https://api.spotify.com/v1/tracks/0N3VOIfkk1Ha...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/0JFx...      228573
# 1     https://api.spotify.com/v1/audio-analysis/5bUV...      273093
# 2     https://api.spotify.com/v1/audio-analysis/1Xqg...      358373
# 3     https://api.spotify.com/v1/audio-analysis/5wXg...      229013
# 4     https://api.spotify.com/v1/audio-analysis/3abz...       34182
# ...                                                 ...         ...
# 7312  https://api.spotify.com/v1/audio-analysis/0hm7...      213627
# 7313  https://api.spotify.com/v1/audio-analysis/5CYb...      271467
# 7314  https://api.spotify.com/v1/audio-analysis/76Qh...      207613
# 7315  https://api.spotify.com/v1/audio-analysis/5vnM...      292413
# 7316  https://api.spotify.com/v1/audio-analysis/0N3V...      277760
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  0
# ...              ...
# 7312               4
# 7313               4
# 7314               4
# 7315               4
# 7316               4
#
# [7317 rows x 21 columns]

# %%
df = df.drop(['Unnamed: 0'], axis = 1)

# %%
df
# Out:
#                           song_title           artist                      id  \
# 0                            Hey Ya!          Outkast  0JFx4l1JZJ6XtMAtlCMiqF
# 1                   No Woman, No Cry           Fugees  5bUVHuzQh5mkvMPjUU074i
# 2                    Can You Feel It     The Jacksons  1XqgxhR3FcJXzFiSG8m6oL
# 3                            Foolish          Ashanti  5wXgj9h0Pc36Rcgwf2qd7A
# 4                  Arigato Interlude  Ms. Lauryn Hill  3abz5HTatP9iv5p8Nm5IT0
# ...                              ...              ...                     ...
# 7312                              XO       John Mayer  0hm785gGfLmHvl9YesZcFP
# 7313               Un-Break My Heart     Toni Braxton  5CYbKUBECU71XChJBP01KE
# 7314                     God Is a DJ        Faithless  76QhWAnwj7aSgAYPOPNXYN
# 7315  I Wanna Be Adored - Remastered  The Stone Roses  5vnMGVPld0mhqVVHMK89y3
# 7316                       Adore You      Miley Cyrus  0N3VOIfkk1Ha2UJiVdeo32
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.657   0.883    4    -6.778     0       0.0526        0.0349
# 1            0.846   0.326    0   -13.909     1       0.1520        0.0134
# 2            0.892   0.638    6    -7.468     0       0.0488        0.0445
# 3            0.620   0.701    0    -5.742     1       0.0624        0.3160
# 4            0.000   0.978   10    -9.615     1       0.0000        0.7990
# ...            ...     ...  ...       ...   ...          ...           ...
# 7312         0.431   0.377    2    -9.753     1       0.0288        0.7490
# 7313         0.620   0.417   11    -9.166     0       0.0286        0.4150
# 7314         0.604   0.893   10    -7.480     0       0.0453        0.1750
# 7315         0.502   0.860    4    -9.251     0       0.0278        0.0123
# 7316         0.552   0.579    0    -7.745     1       0.0332        0.1110
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000    0.3060    0.966   79.397  audio_features
# 1             0.000040    0.2800    0.367   88.988  audio_features
# 2             0.000476    0.2020    0.892  125.359  audio_features
# 3             0.000000    0.1470    0.771   90.059  audio_features
# 4             0.002280    0.9510    0.000    0.000  audio_features
# ...                ...       ...      ...      ...             ...
# 7312          0.000000    0.2110    0.353  173.670  audio_features
# 7313          0.000000    0.0984    0.133  109.904  audio_features
# 7314          0.900000    0.1570    0.366  130.555  audio_features
# 7315          0.240000    0.2160    0.559  112.585  audio_features
# 7316          0.000003    0.1910    0.220  119.748  audio_features
#
#                                        uri  \
# 0     spotify:track:0JFx4l1JZJ6XtMAtlCMiqF
# 1     spotify:track:5bUVHuzQh5mkvMPjUU074i
# 2     spotify:track:1XqgxhR3FcJXzFiSG8m6oL
# 3     spotify:track:5wXgj9h0Pc36Rcgwf2qd7A
# 4     spotify:track:3abz5HTatP9iv5p8Nm5IT0
# ...                                    ...
# 7312  spotify:track:0hm785gGfLmHvl9YesZcFP
# 7313  spotify:track:5CYbKUBECU71XChJBP01KE
# 7314  spotify:track:76QhWAnwj7aSgAYPOPNXYN
# 7315  spotify:track:5vnMGVPld0mhqVVHMK89y3
# 7316  spotify:track:0N3VOIfkk1Ha2UJiVdeo32
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/0JFx4l1JZJ6X...
# 1     https://api.spotify.com/v1/tracks/5bUVHuzQh5mk...
# 2     https://api.spotify.com/v1/tracks/1XqgxhR3FcJX...
# 3     https://api.spotify.com/v1/tracks/5wXgj9h0Pc36...
# 4     https://api.spotify.com/v1/tracks/3abz5HTatP9i...
# ...                                                 ...
# 7312  https://api.spotify.com/v1/tracks/0hm785gGfLmH...
# 7313  https://api.spotify.com/v1/tracks/5CYbKUBECU71...
# 7314  https://api.spotify.com/v1/tracks/76QhWAnwj7aS...
# 7315  https://api.spotify.com/v1/tracks/5vnMGVPld0mh...
# 7316  https://api.spotify.com/v1/tracks/0N3VOIfkk1Ha...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/0JFx...       228573
# 1     https://api.spotify.com/v1/audio-analysis/5bUV...       273093
# 2     https://api.spotify.com/v1/audio-analysis/1Xqg...       358373
# 3     https://api.spotify.com/v1/audio-analysis/5wXg...       229013
# 4     https://api.spotify.com/v1/audio-analysis/3abz...        34182
# ...                                                 ...          ...
# 7312  https://api.spotify.com/v1/audio-analysis/0hm7...       213627
# 7313  https://api.spotify.com/v1/audio-analysis/5CYb...       271467
# 7314  https://api.spotify.com/v1/audio-analysis/76Qh...       207613
# 7315  https://api.spotify.com/v1/audio-analysis/5vnM...       292413
# 7316  https://api.spotify.com/v1/audio-analysis/0N3V...       277760
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  0
# ...              ...
# 7312               4
# 7313               4
# 7314               4
# 7315               4
# 7316               4
#
# [7317 rows x 20 columns]

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.shape
# Out:
# (7317, 20)

# %% [markdown]
# #### Categorical and Numerical

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7317 entries, 0 to 7316
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   song_title        7317 non-null   object
#  1   artist            7317 non-null   object
#  2   id                7317 non-null   object
#  3   danceability      7317 non-null   float64
#  4   energy            7317 non-null   float64
#  5   key               7317 non-null   int64
#  6   loudness          7317 non-null   float64
#  7   mode              7317 non-null   int64
#  8   speechiness       7317 non-null   float64
#  9   acousticness      7317 non-null   float64
#  10  instrumentalness  7317 non-null   float64
#  11  liveness          7317 non-null   float64
#  12  valence           7317 non-null   float64
#  13  tempo             7317 non-null   float64
#  14  type              7317 non-null   object
#  15  uri               7317 non-null   object
#  16  track_href        7317 non-null   object
#  17  analysis_url      7317 non-null   object
#  18  duration_ms       7317 non-null   int64
#  19  time_signature    7317 non-null   int64
# dtypes: float64(9), int64(4), object(7)
# memory usage: 1.1+ MB

# %%
df_fl = df.select_dtypes(np.number)

# %%
df.describe()
# Out:
#        danceability       energy          key     loudness         mode  \
# count   7317.000000  7317.000000  7317.000000  7317.000000  7317.000000
# mean       0.587391     0.607030     5.295476    -8.326448     0.634960
# std        0.168777     0.221907     3.588778     3.553579     0.481474
# min        0.000000     0.001140     0.000000   -40.230000     0.000000
# 25%        0.473000     0.462000     2.000000    -9.753000     0.000000
# 50%        0.602000     0.628000     5.000000    -7.727000     1.000000
# 75%        0.714000     0.784000     8.000000    -6.077000     1.000000
# max        0.969000     0.998000    11.000000    -1.492000     1.000000
#
#        speechiness  acousticness  instrumentalness     liveness      valence  \
# count  7317.000000   7317.000000       7317.000000  7317.000000  7317.000000
# mean      0.091835      0.285053          0.044119     0.208400     0.533108
# std       0.111609      0.300661          0.161981     0.181537     0.253073
# min       0.000000      0.000008          0.000000     0.015700     0.000000
# 25%       0.033100      0.039300          0.000000     0.096200     0.328000
# 50%       0.044700      0.156000          0.000008     0.134000     0.549000
# 75%       0.091200      0.469000          0.000716     0.268000     0.739000
# max       0.948000      0.996000          0.964000     0.994000     0.985000
#
#              tempo   duration_ms  time_signature
# count  7317.000000  7.317000e+03     7317.000000
# mean    114.581336  2.428530e+05        3.913489
# std      29.171158  9.051329e+04        0.399945
# min       0.000000  8.867000e+03        0.000000
# 25%      93.010000  2.049470e+05        4.000000
# 50%     108.873000  2.376530e+05        4.000000
# 75%     130.618000  2.692670e+05        4.000000
# max     216.160000  4.650486e+06        5.000000

# %%
#key, loudness, tempo, duration
#we need to scale

# %% [markdown]
# #### Scaling

# %%
scaler = StandardScaler()
scaler.fit(df_fl)
df_scaled = scaler.transform(df_fl)
df_scaled_df = pd.DataFrame(df_scaled, columns = df_fl.columns)
display(df_fl.head())
print()
display(df_scaled_df.head())
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.657   0.883    4    -6.778     0       0.0526        0.0349
# 1         0.846   0.326    0   -13.909     1       0.1520        0.0134
# 2         0.892   0.638    6    -7.468     0       0.0488        0.0445
# 3         0.620   0.701    0    -5.742     1       0.0624        0.3160
# 4         0.000   0.978   10    -9.615     1       0.0000        0.7990
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0          0.000000     0.306    0.966   79.397       228573               4
# 1          0.000040     0.280    0.367   88.988       273093               4
# 2          0.000476     0.202    0.892  125.359       358373               4
# 3          0.000000     0.147    0.771   90.059       229013               4
# 4          0.002280     0.951    0.000    0.000        34182               0
#    danceability    energy       key  loudness      mode  speechiness  \
# 0      0.412458  1.243718 -0.361004  0.435773 -1.318872    -0.351565
# 1      1.532356 -1.266519 -1.475666 -1.571073  0.758224     0.539105
# 2      1.804924  0.139574  0.196326  0.241589 -1.318872    -0.385614
# 3      0.193218  0.423497 -1.475666  0.727330  0.758224    -0.263752
# 4     -3.480523  1.671855  1.310988 -0.362632  0.758224    -0.822885
#
#    acousticness  instrumentalness  liveness   valence     tempo  duration_ms  \
# 0     -0.832068         -0.272392  0.537669  1.710659 -1.206217    -0.157778
# 1     -0.903582         -0.272147  0.394438 -0.656408 -0.877411     0.334117
# 2     -0.800136         -0.269454 -0.035256  1.418233  0.369488     1.276364
# 3      0.102935         -0.272392 -0.338245  0.940078 -0.840694    -0.152916
# 4      1.709504         -0.258316  4.090906 -2.106681 -3.928167    -2.305576
#
#    time_signature
# 0        0.216322
# 1        0.216322
# 2        0.216322
# 3        0.216322
# 4       -9.785735

# %% [markdown]
# #### Clustering

# %%
kmeans = KMeans(n_clusters=3, random_state=1234)
kmeans.fit(df_scaled_df)
# Out:
# KMeans(n_clusters=3, random_state=1234)

# %%
kmeans.labels_
# Out:
# array([1, 0, 1, ..., 1, 1, 0], dtype=int32)

# %%
labels = kmeans.predict(df_scaled_df)
clusters = np.unique(labels)
for cluster in clusters:
    row_ix = np.where(labels == cluster)
    pyplot.scatter(df_fl.to_numpy()[row_ix, 1], df_fl.to_numpy()[row_ix, 3])
pyplot.show()

# %%
clusters = kmeans.predict(df_scaled_df)
#clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0    3336
# 1    2266
# 2    1715
# dtype: int64

# %%
kmeans.inertia_
# Out:
# 73107.8944252537

# %%
## second trial, k=50

# %%
kmeans2 = KMeans(n_clusters=50,
                init="k-means++",
                n_init=50,  # try with 1, 4, 8, 20, 30, 100...
                max_iter=10,
                tol=0,
                algorithm="elkan",
                random_state=1234)
kmeans2.fit(df_scaled_df)
print(kmeans2.inertia_)
# Out:
# 30414.897083449785

# %% [markdown]
# #### choosing K: elbow method

# %%
K = range(2, 21)
inertia = []

for k in K:
    print("Training a K-Means model with {} clusters! ".format(k))
    print()
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(df_scaled_df)
    inertia.append(kmeans.inertia_)

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
# Out:
# Training a K-Means model with 2 clusters!
#
# Training a K-Means model with 3 clusters!
#
# Training a K-Means model with 4 clusters!
#
# Training a K-Means model with 5 clusters!
#
# Training a K-Means model with 6 clusters!
#
# Training a K-Means model with 7 clusters!
#
# Training a K-Means model with 8 clusters!
#
# Training a K-Means model with 9 clusters!
#
# Training a K-Means model with 10 clusters!
#
# Training a K-Means model with 11 clusters!
#
# Training a K-Means model with 12 clusters!
#
# Training a K-Means model with 13 clusters!
#
# Training a K-Means model with 14 clusters!
#
# Training a K-Means model with 15 clusters!
#
# Training a K-Means model with 16 clusters!
#
# Training a K-Means model with 17 clusters!
#
# Training a K-Means model with 18 clusters!
#
# Training a K-Means model with 19 clusters!
#
# Training a K-Means model with 20 clusters!
# ([<matplotlib.axis.XTick at 0x7f88db7993a0>,
#   <matplotlib.axis.XTick at 0x7f88db799370>,
#   <matplotlib.axis.XTick at 0x7f88b94f2dc0>,
#   <matplotlib.axis.XTick at 0x7f88e85bdf10>,
#   <matplotlib.axis.XTick at 0x7f88e85cf6a0>,
#   <matplotlib.axis.XTick at 0x7f88e85cfdf0>,
#   <matplotlib.axis.XTick at 0x7f88e85d4580>,
#   <matplotlib.axis.XTick at 0x7f88e85cfac0>,
#   <matplotlib.axis.XTick at 0x7f88e85d45b0>,
#   <matplotlib.axis.XTick at 0x7f88e85db130>,
#   <matplotlib.axis.XTick at 0x7f88e85db7c0>,
#   <matplotlib.axis.XTick at 0x7f88e85dbf10>,
#   <matplotlib.axis.XTick at 0x7f88e85e16a0>,
#   <matplotlib.axis.XTick at 0x7f88e85e1df0>,
#   <matplotlib.axis.XTick at 0x7f88e85e1700>,
#   <matplotlib.axis.XTick at 0x7f88e85db3a0>,
#   <matplotlib.axis.XTick at 0x7f88e85e72e0>,
#   <matplotlib.axis.XTick at 0x7f88e85e7970>,
#   <matplotlib.axis.XTick at 0x7f88e85f0100>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# #### Silouhette

# %%
K = range(2, 20)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(df_scaled_df)
    
    silhouette.append(silhouette_score(df_scaled_df, kmeans.predict(df_scaled_df)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Silhouette Method showing the optimal k')
# Out:
# Text(0.5, 1.0, 'Silhouette Method showing the optimal k')

# %%
## Trial 3, k=6

# %%
kmeans3 = KMeans(n_clusters=6, random_state=1234)
kmeans3.fit(df_scaled_df)
# Out:
# KMeans(n_clusters=6, random_state=1234)

# %%
# assign a cluster to each example
labels = kmeans3.predict(df_scaled_df)
# retrieve unique clusters
clusters = np.unique(labels)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = np.where(labels == cluster)
    # create scatter of these samples
    pyplot.scatter(df_fl.to_numpy()[row_ix, 1], df_fl.to_numpy()[row_ix, 3])
    # show the plot
pyplot.show()

# %%
clusters = kmeans3.predict(df_scaled_df)
#clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0     330
# 1    1882
# 2    1359
# 3    2643
# 4     519
# 5     584
# dtype: int64

# %%
## adding a cluster column to orig df

# %%
kmeans3.labels_
# Out:
# array([1, 3, 1, ..., 0, 1, 3], dtype=int32)

# %%
labels3 = np.unique(kmeans3)
labels3
# Out:
# array([KMeans(n_clusters=6, random_state=1234)], dtype=object)

# %%
kmeans3.inertia_
# Out:
# 60414.92521335484

# %%
df["cluster"] = clusters
df
# Out:
#                           song_title           artist                      id  \
# 0                            Hey Ya!          Outkast  0JFx4l1JZJ6XtMAtlCMiqF
# 1                   No Woman, No Cry           Fugees  5bUVHuzQh5mkvMPjUU074i
# 2                    Can You Feel It     The Jacksons  1XqgxhR3FcJXzFiSG8m6oL
# 3                            Foolish          Ashanti  5wXgj9h0Pc36Rcgwf2qd7A
# 4                  Arigato Interlude  Ms. Lauryn Hill  3abz5HTatP9iv5p8Nm5IT0
# ...                              ...              ...                     ...
# 7312                              XO       John Mayer  0hm785gGfLmHvl9YesZcFP
# 7313               Un-Break My Heart     Toni Braxton  5CYbKUBECU71XChJBP01KE
# 7314                     God Is a DJ        Faithless  76QhWAnwj7aSgAYPOPNXYN
# 7315  I Wanna Be Adored - Remastered  The Stone Roses  5vnMGVPld0mhqVVHMK89y3
# 7316                       Adore You      Miley Cyrus  0N3VOIfkk1Ha2UJiVdeo32
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.657   0.883    4    -6.778     0       0.0526        0.0349
# 1            0.846   0.326    0   -13.909     1       0.1520        0.0134
# 2            0.892   0.638    6    -7.468     0       0.0488        0.0445
# 3            0.620   0.701    0    -5.742     1       0.0624        0.3160
# 4            0.000   0.978   10    -9.615     1       0.0000        0.7990
# ...            ...     ...  ...       ...   ...          ...           ...
# 7312         0.431   0.377    2    -9.753     1       0.0288        0.7490
# 7313         0.620   0.417   11    -9.166     0       0.0286        0.4150
# 7314         0.604   0.893   10    -7.480     0       0.0453        0.1750
# 7315         0.502   0.860    4    -9.251     0       0.0278        0.0123
# 7316         0.552   0.579    0    -7.745     1       0.0332        0.1110
#
#       ...  liveness  valence    tempo            type  \
# 0     ...    0.3060    0.966   79.397  audio_features
# 1     ...    0.2800    0.367   88.988  audio_features
# 2     ...    0.2020    0.892  125.359  audio_features
# 3     ...    0.1470    0.771   90.059  audio_features
# 4     ...    0.9510    0.000    0.000  audio_features
# ...   ...       ...      ...      ...             ...
# 7312  ...    0.2110    0.353  173.670  audio_features
# 7313  ...    0.0984    0.133  109.904  audio_features
# 7314  ...    0.1570    0.366  130.555  audio_features
# 7315  ...    0.2160    0.559  112.585  audio_features
# 7316  ...    0.1910    0.220  119.748  audio_features
#
#                                        uri  \
# 0     spotify:track:0JFx4l1JZJ6XtMAtlCMiqF
# 1     spotify:track:5bUVHuzQh5mkvMPjUU074i
# 2     spotify:track:1XqgxhR3FcJXzFiSG8m6oL
# 3     spotify:track:5wXgj9h0Pc36Rcgwf2qd7A
# 4     spotify:track:3abz5HTatP9iv5p8Nm5IT0
# ...                                    ...
# 7312  spotify:track:0hm785gGfLmHvl9YesZcFP
# 7313  spotify:track:5CYbKUBECU71XChJBP01KE
# 7314  spotify:track:76QhWAnwj7aSgAYPOPNXYN
# 7315  spotify:track:5vnMGVPld0mhqVVHMK89y3
# 7316  spotify:track:0N3VOIfkk1Ha2UJiVdeo32
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/0JFx4l1JZJ6X...
# 1     https://api.spotify.com/v1/tracks/5bUVHuzQh5mk...
# 2     https://api.spotify.com/v1/tracks/1XqgxhR3FcJX...
# 3     https://api.spotify.com/v1/tracks/5wXgj9h0Pc36...
# 4     https://api.spotify.com/v1/tracks/3abz5HTatP9i...
# ...                                                 ...
# 7312  https://api.spotify.com/v1/tracks/0hm785gGfLmH...
# 7313  https://api.spotify.com/v1/tracks/5CYbKUBECU71...
# 7314  https://api.spotify.com/v1/tracks/76QhWAnwj7aS...
# 7315  https://api.spotify.com/v1/tracks/5vnMGVPld0mh...
# 7316  https://api.spotify.com/v1/tracks/0N3VOIfkk1Ha...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/0JFx...      228573
# 1     https://api.spotify.com/v1/audio-analysis/5bUV...      273093
# 2     https://api.spotify.com/v1/audio-analysis/1Xqg...      358373
# 3     https://api.spotify.com/v1/audio-analysis/5wXg...      229013
# 4     https://api.spotify.com/v1/audio-analysis/3abz...       34182
# ...                                                 ...         ...
# 7312  https://api.spotify.com/v1/audio-analysis/0hm7...      213627
# 7313  https://api.spotify.com/v1/audio-analysis/5CYb...      271467
# 7314  https://api.spotify.com/v1/audio-analysis/76Qh...      207613
# 7315  https://api.spotify.com/v1/audio-analysis/5vnM...      292413
# 7316  https://api.spotify.com/v1/audio-analysis/0N3V...      277760
#
#       time_signature  cluster
# 0                  4        1
# 1                  4        3
# 2                  4        1
# 3                  4        3
# 4                  0        4
# ...              ...      ...
# 7312               4        2
# 7313               4        2
# 7314               4        0
# 7315               4        1
# 7316               4        3
#
# [7317 rows x 21 columns]

# %%
df.to_csv("clustered_songs_df.csv")

# %%
## saving the pickle

# %%
with open("scaler.pickle", "wb") as f:
    pickle.dump(scaler,f)
with open("kmeans3.pickle", "wb") as f:
    pickle.dump(kmeans3,f)

# %%
with open("scaler.pickle", "rb") as f: 
        scaler = pickle.load(f) 
with open("kmeans3.pickle", "rb") as f: 
        scaler = pickle.load(f)

# %% [markdown]
# #### Putting the data together

# %%
hot_songs = pd.read_csv("top_100_songs.csv")

# %%
hot_songs.drop(['Unnamed: 0'], axis = 1, inplace= True)

# %%
hot_songs
# Out:
#                          name  \
# 0   we don't talk about bruno
# 1       do we have a problem?
# 2                  easy on me
# 3                  heat waves
# 4                        stay
# ..                        ...
# 95                       iffy
# 96              when i'm gone
# 97                 fair trade
# 98              megan's piano
# 99            moth to a flame
#
#                                                artist
# 0   carolina gaitan, mauro castillo, adassa, rhenz...
# 1                              nicki minaj x lil baby
# 2                                               adele
# 3                                       glass animals
# 4                       the kid laroi & justin bieber
# ..                                                ...
# 95                                        chris brown
# 96                                alesso / katy perry
# 97                       drake featuring travis scott
# 98                                megan thee stallion
# 99                   swedish house mafia & the weeknd
#
# [100 rows x 2 columns]

# %%
## import config 
#Initialize SpotiPy with user credential

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= "d4726b15e5b34b0fa3c825aaea90d658",
                                                           client_secret= "70c9f746187d4b94976e58afcb88cf64"))

# %% [markdown]
# ### user_song

# %%
results = sp.search(q= user_input,limit=1,market="GB")
results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/nx/7crq4wx155z00jtfy6fbs9bw0000gn/T/ipykernel_3323/2639793074.py in <module>
# ----> 1 results = sp.search(q= user_input,limit=1,market="GB")
#       2 results
#
# NameError: name 'user_input' is not defined

# %%
track_id=results['tracks']['items'][0]['external_urls']["spotify"][31:]
track_id

# %%
from IPython.display import IFrame


IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )

# %% [markdown]
# #### Getting uri

# %%
pprint.pprint(results['tracks']['items'][0]['uri'])
results["tracks"]["items"][0]["uri"]

# %% [markdown]
# #### Getting the audio features for the input song

# %%
input_song = sp.audio_features(results["tracks"]["items"][0]["uri"])[0]

# %%
input_song

# %%
input_song = pd.DataFrame([input_song]) # turn the features into a data frame to add it as a column

# %%
## drop unnecesasary features
input_song_num = input_song.select_dtypes(np.number)
input_song_num

# %%
## Transform input_song

# %%
input_song_sc = scaler.transform(input_song_num)
song_trans_df = pd.DataFrame(input_song_sc, columns = input_song_num.columns)
display(input_song_num.head())
print()
display(song_trans_df.head())

# %%
df

# %%
user_song_cluster = kmeans3.predict(song_trans_df)[0]

# %%
recommended_song = df[df["cluster"] == user_song_cluster].sample()
recommended_song

# %%
recommended_song_id = recommended_song["id"].iat[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/nx/7crq4wx155z00jtfy6fbs9bw0000gn/T/ipykernel_3323/3697016400.py in <module>
# ----> 1 recommended_song_id = recommended_song["id"].iat[0]
#
# NameError: name 'recommended_song' is not defined

# %% [markdown]
# ### end: user_song

# %%
from IPython.display import IFrame


IFrame(src="https://open.spotify.com/embed/track/"+recommended_song_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/nx/7crq4wx155z00jtfy6fbs9bw0000gn/T/ipykernel_3323/323660065.py in <module>
#       2
#       3
# ----> 4 IFrame(src="https://open.spotify.com/embed/track/"+recommended_song_id,
#       5        width="320",
#       6        height="80",
#
# NameError: name 'recommended_song_id' is not defined

# %%
print("You might also like the song: " + recommended_song["song_title"].iat[0] + " by " + recommended_song["artist"].iat[0] + ".")

# %%
for song in hot_songs[["name","artist"]].iterrows():
    user_input = input("Write down a song title: ")
    if user_input.lower() in list(hot_songs["name"]):
        random_song = random.choice(hot_songs["name"])
        song_artist = hot_songs.loc[hot_songs["name"] == random_song, "artist"].values[0]
        
        print("You may also like this song: ", random_song, "from", song_artist)
        print("Thanks for using the music recommender.")
        break

    else user_input not in hot_songs[["name","artist"]].iterrows():
        print("You might also like the song: " + recommended_song["song_title"].iat[0] + " by " + recommended_song["artist"].iat[0] + ".") 
        break
