# %%
import config
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.c_id,
                                                           client_secret= config.c_se))

# %%
results = sp.search(q="Flesh World",limit=1,market="GB")
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Flesh+World&type=track&market=GB&offset=0&limit=1',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3OoNpyvA82LedOZWG3WE8Z'},
#        'href': 'https://api.spotify.com/v1/artists/3OoNpyvA82LedOZWG3WE8Z',
#        'id': '3OoNpyvA82LedOZWG3WE8Z',
#        'name': 'Coeo',
#        'type': 'artist',
#        'uri': 'spotify:artist:3OoNpyvA82LedOZWG3WE8Z'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6h9jdXMrcq8fMeRVgjqapc'},
#      'href': 'https://api.spotify.com/v1/albums/6h9jdXMrcq8fMeRVgjqapc',
#      'id': '6h9jdXMrcq8fMeRVgjqapc',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273344cfda5f334e81ad51aa464',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02344cfda5f334e81ad51aa464',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851344cfda5f334e81ad51aa464',
#        'width': 64}],
#      'name': 'Flesh World',
#      'release_date': '2017-10-06',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:6h9jdXMrcq8fMeRVgjqapc'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3OoNpyvA82LedOZWG3WE8Z'},
#       'href': 'https://api.spotify.com/v1/artists/3OoNpyvA82LedOZWG3WE8Z',
#       'id': '3OoNpyvA82LedOZWG3WE8Z',
#       'name': 'Coeo',
#       'type': 'artist',
#       'uri': 'spotify:artist:3OoNpyvA82LedOZWG3WE8Z'}],
#     'disc_number': 1,
#     'duration_ms': 398139,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEBY41200289'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5ZqvrH3XyHXXJ7vvy3b9lF'},
#     'href': 'https://api.spotify.com/v1/tracks/5ZqvrH3XyHXXJ7vvy3b9lF',
#     'id': '5ZqvrH3XyHXXJ7vvy3b9lF',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Flesh World',
#     'popularity': 35,
#     'preview_url': 'https://p.scdn.co/mp3-preview/16c11755be366b5c4ae65bb80286b85334a62d7a?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5ZqvrH3XyHXXJ7vvy3b9lF'}],
#   'limit': 1,
#   'next': 'https://api.spotify.com/v1/search?query=Flesh+World&type=track&market=GB&offset=1&limit=1',
#   'offset': 0,
#   'previous': None,
#   'total': 665}}

# %%
results.keys()
# Out:
# dict_keys(['tracks'])

# %%
results['tracks']['items'][0]
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3OoNpyvA82LedOZWG3WE8Z'},
#     'href': 'https://api.spotify.com/v1/artists/3OoNpyvA82LedOZWG3WE8Z',
#     'id': '3OoNpyvA82LedOZWG3WE8Z',
#     'name': 'Coeo',
#     'type': 'artist',
#     'uri': 'spotify:artist:3OoNpyvA82LedOZWG3WE8Z'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6h9jdXMrcq8fMeRVgjqapc'},
#   'href': 'https://api.spotify.com/v1/albums/6h9jdXMrcq8fMeRVgjqapc',
#   'id': '6h9jdXMrcq8fMeRVgjqapc',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273344cfda5f334e81ad51aa464',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02344cfda5f334e81ad51aa464',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851344cfda5f334e81ad51aa464',
#     'width': 64}],
#   'name': 'Flesh World',
#   'release_date': '2017-10-06',
#   'release_date_precision': 'day',
#   'total_tracks': 3,
#   'type': 'album',
#   'uri': 'spotify:album:6h9jdXMrcq8fMeRVgjqapc'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3OoNpyvA82LedOZWG3WE8Z'},
#    'href': 'https://api.spotify.com/v1/artists/3OoNpyvA82LedOZWG3WE8Z',
#    'id': '3OoNpyvA82LedOZWG3WE8Z',
#    'name': 'Coeo',
#    'type': 'artist',
#    'uri': 'spotify:artist:3OoNpyvA82LedOZWG3WE8Z'}],
#  'disc_number': 1,
#  'duration_ms': 398139,
#  'explicit': False,
#  'external_ids': {'isrc': 'DEBY41200289'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/5ZqvrH3XyHXXJ7vvy3b9lF'},
#  'href': 'https://api.spotify.com/v1/tracks/5ZqvrH3XyHXXJ7vvy3b9lF',
#  'id': '5ZqvrH3XyHXXJ7vvy3b9lF',
#  'is_local': False,
#  'is_playable': True,
#  'name': 'Flesh World',
#  'popularity': 35,
#  'preview_url': 'https://p.scdn.co/mp3-preview/16c11755be366b5c4ae65bb80286b85334a62d7a?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:5ZqvrH3XyHXXJ7vvy3b9lF'}

# %%
results['tracks']['items'][0]['id']
# Out:
# '5ZqvrH3XyHXXJ7vvy3b9lF'

# %%
for item in results['tracks']['items']:
    print("The name of song is: '{}' and the id is: {}".format(item['name'],item["id"]))
# Out:
# The name of song is: 'Flesh World' and the id is: 5ZqvrH3XyHXXJ7vvy3b9lF

# %%
import pandas as pd

song = sp.search(q="Flesh World", limit=9,market="GB") 
song
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Flesh+World&type=track&market=GB&offset=0&limit=9',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3OoNpyvA82LedOZWG3WE8Z'},
#        'href': 'https://api.spotify.com/v1/artists/3OoNpyvA82LedOZWG3WE8Z',
#        'id': '3OoNpyvA82LedOZWG3WE8Z',
#        'name': 'Coeo',
#        'type': 'artist',
#        'uri': 'spotify:artist:3OoNpyvA82LedOZWG3WE8Z'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6h9jdXMrcq8fMeRVgjqapc'},
#      'href': 'https://api.spotify.com/v1/albums/6h9jdXMrcq8fMeRVgjqapc',
#      'id': '6h9jdXMrcq8fMeRVgjqapc',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273344cfda5f334e81ad51aa464',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02344cfda5f334e81ad51aa464',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851344cfda5f334e81ad51aa464',
#        'width': 64}],
#      'name': 'Flesh World',
#      'release_date': '2017-10-06',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:6h9jdXMrcq8fMeRVgjqapc'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3OoNpyvA82LedOZWG3WE8Z'},
#       'href': 'https://api.spotify.com/v1/artists/3OoNpyvA82LedOZWG3WE8Z',
#       'id': '3OoNpyvA82LedOZWG3WE8Z',
#       'name': 'Coeo',
#       'type': 'artist',
#       'uri': 'spotify:artist:3OoNpyvA82LedOZWG3WE8Z'}],
#     'disc_number': 1,
#     'duration_ms': 398139,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEBY41200289'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5ZqvrH3XyHXXJ7vvy3b9lF'},
#     'href': 'https://api.spotify.com/v1/tracks/5ZqvrH3XyHXXJ7vvy3b9lF',
#     'id': '5ZqvrH3XyHXXJ7vvy3b9lF',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Flesh World',
#     'popularity': 35,
#     'preview_url': 'https://p.scdn.co/mp3-preview/16c11755be366b5c4ae65bb80286b85334a62d7a?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5ZqvrH3XyHXXJ7vvy3b9lF'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6FfjnGXMhxSsJTuGLWBDth'},
#        'href': 'https://api.spotify.com/v1/artists/6FfjnGXMhxSsJTuGLWBDth',
#        'id': '6FfjnGXMhxSsJTuGLWBDth',
#        'name': 'HEALTH',
#        'type': 'artist',
#        'uri': 'spotify:artist:6FfjnGXMhxSsJTuGLWBDth'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2a5KZ4rwrXIm28LvcyjYz5'},
#      'href': 'https://api.spotify.com/v1/albums/2a5KZ4rwrXIm28LvcyjYz5',
#      'id': '2a5KZ4rwrXIm28LvcyjYz5',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273499959959c343367a0e1383b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02499959959c343367a0e1383b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851499959959c343367a0e1383b',
#        'width': 64}],
#      'name': 'DEATH MAGIC',
#      'release_date': '2015-08-07',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:2a5KZ4rwrXIm28LvcyjYz5'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6FfjnGXMhxSsJTuGLWBDth'},
#       'href': 'https://api.spotify.com/v1/artists/6FfjnGXMhxSsJTuGLWBDth',
#       'id': '6FfjnGXMhxSsJTuGLWBDth',
#       'name': 'HEALTH',
#       'type': 'artist',
#       'uri': 'spotify:artist:6FfjnGXMhxSsJTuGLWBDth'}],
#     'disc_number': 1,
#     'duration_ms': 234493,
#     'explicit': False,
#     'external_ids': {'isrc': 'USC4R1500546'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1i2gMeXwREbvnJe6Uh8w6A'},
#     'href': 'https://api.spotify.com/v1/tracks/1i2gMeXwREbvnJe6Uh8w6A',
#     'id': '1i2gMeXwREbvnJe6Uh8w6A',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'FLESH WORLD (UK)',
#     'popularity': 33,
#     'preview_url': None,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:1i2gMeXwREbvnJe6Uh8w6A'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0sXhBmVgBTDxkQb8CUbhhR'},
#        'href': 'https://api.spotify.com/v1/artists/0sXhBmVgBTDxkQb8CUbhhR',
#        'id': '0sXhBmVgBTDxkQb8CUbhhR',
#        'name': 'Coops',
#        'type': 'artist',
#        'uri': 'spotify:artist:0sXhBmVgBTDxkQb8CUbhhR'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2E5lsUZR2yWA079oAbzK4H'},
#      'href': 'https://api.spotify.com/v1/albums/2E5lsUZR2yWA079oAbzK4H',
#      'id': '2E5lsUZR2yWA079oAbzK4H',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733e25da1dbebdaa14c6ce0f79',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023e25da1dbebdaa14c6ce0f79',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513e25da1dbebdaa14c6ce0f79',
#        'width': 64}],
#      'name': 'LIFE IN THE FLESH',
#      'release_date': '2018-09-28',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:2E5lsUZR2yWA079oAbzK4H'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0sXhBmVgBTDxkQb8CUbhhR'},
#       'href': 'https://api.spotify.com/v1/artists/0sXhBmVgBTDxkQb8CUbhhR',
#       'id': '0sXhBmVgBTDxkQb8CUbhhR',
#       'name': 'Coops',
#       'type': 'artist',
#       'uri': 'spotify:artist:0sXhBmVgBTDxkQb8CUbhhR'}],
#     'disc_number': 1,
#     'duration_ms': 204453,
#     'explicit': True,
#     'external_ids': {'isrc': 'GB6ZW1800191'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3xKVUJjEOdR8ncs0RrWlzU'},
#     'href': 'https://api.spotify.com/v1/tracks/3xKVUJjEOdR8ncs0RrWlzU',
#     'id': '3xKVUJjEOdR8ncs0RrWlzU',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Cold World',
#     'popularity': 22,
#     'preview_url': 'https://p.scdn.co/mp3-preview/42cb47b22c77cde5f6ec8b1c55e64589682a2ae6?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:3xKVUJjEOdR8ncs0RrWlzU'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3OoNpyvA82LedOZWG3WE8Z'},
#        'href': 'https://api.spotify.com/v1/artists/3OoNpyvA82LedOZWG3WE8Z',
#        'id': '3OoNpyvA82LedOZWG3WE8Z',
#        'name': 'Coeo',
#        'type': 'artist',
#        'uri': 'spotify:artist:3OoNpyvA82LedOZWG3WE8Z'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6h9jdXMrcq8fMeRVgjqapc'},
#      'href': 'https://api.spotify.com/v1/albums/6h9jdXMrcq8fMeRVgjqapc',
#      'id': '6h9jdXMrcq8fMeRVgjqapc',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273344cfda5f334e81ad51aa464',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02344cfda5f334e81ad51aa464',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851344cfda5f334e81ad51aa464',
#        'width': 64}],
#      'name': 'Flesh World',
#      'release_date': '2017-10-06',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:6h9jdXMrcq8fMeRVgjqapc'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3OoNpyvA82LedOZWG3WE8Z'},
#       'href': 'https://api.spotify.com/v1/artists/3OoNpyvA82LedOZWG3WE8Z',
#       'id': '3OoNpyvA82LedOZWG3WE8Z',
#       'name': 'Coeo',
#       'type': 'artist',
#       'uri': 'spotify:artist:3OoNpyvA82LedOZWG3WE8Z'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3sySIHNL0hqR7eOlm3LNTH'},
#       'href': 'https://api.spotify.com/v1/artists/3sySIHNL0hqR7eOlm3LNTH',
#       'id': '3sySIHNL0hqR7eOlm3LNTH',
#       'name': 'Kapote',
#       'type': 'artist',
#       'uri': 'spotify:artist:3sySIHNL0hqR7eOlm3LNTH'}],
#     'disc_number': 1,
#     'duration_ms': 599247,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEBY41200291'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5P3iHoGYKwPIdvBec1Py36'},
#     'href': 'https://api.spotify.com/v1/tracks/5P3iHoGYKwPIdvBec1Py36',
#     'id': '5P3iHoGYKwPIdvBec1Py36',
#     'is_local': False,
#     'is_playable': True,
#     'name': "Flesh World - Kapote's Drum Jam Version",
#     'popularity': 22,
#     'preview_url': 'https://p.scdn.co/mp3-preview/495dff753b564deaa59894640ec4ccc82aae282c?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:5P3iHoGYKwPIdvBec1Py36'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4L74W177Wc8s7WrQHbVaXt'},
#        'href': 'https://api.spotify.com/v1/artists/4L74W177Wc8s7WrQHbVaXt',
#        'id': '4L74W177Wc8s7WrQHbVaXt',
#        'name': 'Café del Mar',
#        'type': 'artist',
#        'uri': 'spotify:artist:4L74W177Wc8s7WrQHbVaXt'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3Xgc8kJPLq8Ck7a1BULNjf'},
#      'href': 'https://api.spotify.com/v1/albums/3Xgc8kJPLq8Ck7a1BULNjf',
#      'id': '3Xgc8kJPLq8Ck7a1BULNjf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732bda1e441716f3d4c293da75',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022bda1e441716f3d4c293da75',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512bda1e441716f3d4c293da75',
#        'width': 64}],
#      'name': 'Café del Mar Chillhouse Mix XI (DJ Mix)',
#      'release_date': '2020-07-21',
#      'release_date_precision': 'day',
#      'total_tracks': 26,
#      'type': 'album',
#      'uri': 'spotify:album:3Xgc8kJPLq8Ck7a1BULNjf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/63d7s0b6Ibagd11SnscjAO'},
#       'href': 'https://api.spotify.com/v1/artists/63d7s0b6Ibagd11SnscjAO',
#       'id': '63d7s0b6Ibagd11SnscjAO',
#       'name': 'Coeo',
#       'type': 'artist',
#       'uri': 'spotify:artist:63d7s0b6Ibagd11SnscjAO'}],
#     'disc_number': 1,
#     'duration_ms': 351912,
#     'explicit': False,
#     'external_ids': {'isrc': 'ES8742024102'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3p8sSQ01EWfuGeNpy6SAmb'},
#     'href': 'https://api.spotify.com/v1/tracks/3p8sSQ01EWfuGeNpy6SAmb',
#     'id': '3p8sSQ01EWfuGeNpy6SAmb',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Flesh World - Mixed',
#     'popularity': 26,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e86f94fc47876b1af2411d4ad44775134e54f6ab?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:3p8sSQ01EWfuGeNpy6SAmb'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5NhSUk5Sygly90DDO78eLK'},
#        'href': 'https://api.spotify.com/v1/artists/5NhSUk5Sygly90DDO78eLK',
#        'id': '5NhSUk5Sygly90DDO78eLK',
#        'name': 'Mr. Irish Bastard',
#        'type': 'artist',
#        'uri': 'spotify:artist:5NhSUk5Sygly90DDO78eLK'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2dOBGqdNX6RRgKhFHlD77b'},
#      'href': 'https://api.spotify.com/v1/albums/2dOBGqdNX6RRgKhFHlD77b',
#      'id': '2dOBGqdNX6RRgKhFHlD77b',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27332e7c12e4d03a10fe0782473',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0232e7c12e4d03a10fe0782473',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485132e7c12e4d03a10fe0782473',
#        'width': 64}],
#      'name': 'The World, the Flesh & the Devil',
#      'release_date': '2015-05-08',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:2dOBGqdNX6RRgKhFHlD77b'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5NhSUk5Sygly90DDO78eLK'},
#       'href': 'https://api.spotify.com/v1/artists/5NhSUk5Sygly90DDO78eLK',
#       'id': '5NhSUk5Sygly90DDO78eLK',
#       'name': 'Mr. Irish Bastard',
#       'type': 'artist',
#       'uri': 'spotify:artist:5NhSUk5Sygly90DDO78eLK'}],
#     'disc_number': 1,
#     'duration_ms': 215306,
#     'explicit': False,
#     'external_ids': {'isrc': 'DETU81500005'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4Mp8P2pDUV7B2PwLSWW1pz'},
#     'href': 'https://api.spotify.com/v1/tracks/4Mp8P2pDUV7B2PwLSWW1pz',
#     'id': '4Mp8P2pDUV7B2PwLSWW1pz',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'I Hope They Sell Beer in Hell',
#     'popularity': 43,
#     'preview_url': 'https://p.scdn.co/mp3-preview/117321208b5c61b3458cbe2154308867d9fc2eeb?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:4Mp8P2pDUV7B2PwLSWW1pz'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7xQanGhMDlJYOOBCoZ20cX'},
#        'href': 'https://api.spotify.com/v1/artists/7xQanGhMDlJYOOBCoZ20cX',
#        'id': '7xQanGhMDlJYOOBCoZ20cX',
#        'name': 'Flesh',
#        'type': 'artist',
#        'uri': 'spotify:artist:7xQanGhMDlJYOOBCoZ20cX'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2z40oUcDRH1LnK1yEGBzby'},
#      'href': 'https://api.spotify.com/v1/albums/2z40oUcDRH1LnK1yEGBzby',
#      'id': '2z40oUcDRH1LnK1yEGBzby',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ce3d058be28eb2d43536d07e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ce3d058be28eb2d43536d07e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ce3d058be28eb2d43536d07e',
#        'width': 64}],
#      'name': 'Come and See This Cruel World',
#      'release_date': '2016-01-31',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:2z40oUcDRH1LnK1yEGBzby'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7xQanGhMDlJYOOBCoZ20cX'},
#       'href': 'https://api.spotify.com/v1/artists/7xQanGhMDlJYOOBCoZ20cX',
#       'id': '7xQanGhMDlJYOOBCoZ20cX',
#       'name': 'Flesh',
#       'type': 'artist',
#       'uri': 'spotify:artist:7xQanGhMDlJYOOBCoZ20cX'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7821Oa0W0vHuEFaHyrzYur'},
#       'href': 'https://api.spotify.com/v1/artists/7821Oa0W0vHuEFaHyrzYur',
#       'id': '7821Oa0W0vHuEFaHyrzYur',
#       'name': 'BΛNMΛSKIM',
#       'type': 'artist',
#       'uri': 'spotify:artist:7821Oa0W0vHuEFaHyrzYur'}],
#     'disc_number': 1,
#     'duration_ms': 343288,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCADR1812766'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0LBwpoUs3Hy7158PjAeN3i'},
#     'href': 'https://api.spotify.com/v1/tracks/0LBwpoUs3Hy7158PjAeN3i',
#     'id': '0LBwpoUs3Hy7158PjAeN3i',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Black Crown',
#     'popularity': 37,
#     'preview_url': 'https://p.scdn.co/mp3-preview/51f73159d68642eca7f9a414c9bb88954ff94516?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:0LBwpoUs3Hy7158PjAeN3i'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5CNR5mJJPAhMamFWQ9xJxD'},
#        'href': 'https://api.spotify.com/v1/artists/5CNR5mJJPAhMamFWQ9xJxD',
#        'id': '5CNR5mJJPAhMamFWQ9xJxD',
#        'name': 'In Solitude',
#        'type': 'artist',
#        'uri': 'spotify:artist:5CNR5mJJPAhMamFWQ9xJxD'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/25SYB9zU1aK8G4jjjVmy7s'},
#      'href': 'https://api.spotify.com/v1/albums/25SYB9zU1aK8G4jjjVmy7s',
#      'id': '25SYB9zU1aK8G4jjjVmy7s',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a03ee2c0adedea1d5da6e796',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a03ee2c0adedea1d5da6e796',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a03ee2c0adedea1d5da6e796',
#        'width': 64}],
#      'name': 'The World; The Flesh: The Devil',
#      'release_date': '2011-05-23',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:25SYB9zU1aK8G4jjjVmy7s'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5CNR5mJJPAhMamFWQ9xJxD'},
#       'href': 'https://api.spotify.com/v1/artists/5CNR5mJJPAhMamFWQ9xJxD',
#       'id': '5CNR5mJJPAhMamFWQ9xJxD',
#       'name': 'In Solitude',
#       'type': 'artist',
#       'uri': 'spotify:artist:5CNR5mJJPAhMamFWQ9xJxD'}],
#     'disc_number': 1,
#     'duration_ms': 371186,
#     'explicit': False,
#     'external_ids': {'isrc': 'USMBR1108192'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/18kKRFSgq9pv5cpuXqC0Vq'},
#     'href': 'https://api.spotify.com/v1/tracks/18kKRFSgq9pv5cpuXqC0Vq',
#     'id': '18kKRFSgq9pv5cpuXqC0Vq',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'To Her Darkness',
#     'popularity': 37,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ae204660d9846fcfdb8d22e5b4615120e58a3b31?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:18kKRFSgq9pv5cpuXqC0Vq'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3OoNpyvA82LedOZWG3WE8Z'},
#        'href': 'https://api.spotify.com/v1/artists/3OoNpyvA82LedOZWG3WE8Z',
#        'id': '3OoNpyvA82LedOZWG3WE8Z',
#        'name': 'Coeo',
#        'type': 'artist',
#        'uri': 'spotify:artist:3OoNpyvA82LedOZWG3WE8Z'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6h9jdXMrcq8fMeRVgjqapc'},
#      'href': 'https://api.spotify.com/v1/albums/6h9jdXMrcq8fMeRVgjqapc',
#      'id': '6h9jdXMrcq8fMeRVgjqapc',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273344cfda5f334e81ad51aa464',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02344cfda5f334e81ad51aa464',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851344cfda5f334e81ad51aa464',
#        'width': 64}],
#      'name': 'Flesh World',
#      'release_date': '2017-10-06',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:6h9jdXMrcq8fMeRVgjqapc'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3OoNpyvA82LedOZWG3WE8Z'},
#       'href': 'https://api.spotify.com/v1/artists/3OoNpyvA82LedOZWG3WE8Z',
#       'id': '3OoNpyvA82LedOZWG3WE8Z',
#       'name': 'Coeo',
#       'type': 'artist',
#       'uri': 'spotify:artist:3OoNpyvA82LedOZWG3WE8Z'}],
#     'disc_number': 1,
#     'duration_ms': 430880,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEBY41200290'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5MXIYhseXGWR3oE8PORqoP'},
#     'href': 'https://api.spotify.com/v1/tracks/5MXIYhseXGWR3oE8PORqoP',
#     'id': '5MXIYhseXGWR3oE8PORqoP',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'In Motion',
#     'popularity': 25,
#     'preview_url': 'https://p.scdn.co/mp3-preview/05a04a29dd3445731722c17b0e0109ab0f8992bb?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:5MXIYhseXGWR3oE8PORqoP'}],
#   'limit': 9,
#   'next': 'https://api.spotify.com/v1/search?query=Flesh+World&type=track&market=GB&offset=9&limit=9',
#   'offset': 0,
#   'previous': None,
#   'total': 665}}

# %%
len(song["tracks"]["items"])
# Out:
# 9

# %%
#pprint.pprint(song['tracks']['items'][0]['uri'])
song["tracks"]["items"][0]["uri"]
# Out:
# 'spotify:track:5ZqvrH3XyHXXJ7vvy3b9lF'

# %% [markdown]
# ## Json

# %%
print("The json file has the following keys: ",list(results.keys())) # We can see that we only have tracks
print("")
print("The 'tracks' key has the following child keys: ",list(results["tracks"].keys())) # Let's check the values
print("")
print("The query we made is: ",results["tracks"]["href"]) # Query we have searched 
print("")
print("The song's info is contained in: ",results["tracks"]["items"]) #items (actual tracks)
print("")
print("The limit of the query we've made is: ",results["tracks"]["limit"]) #Limit we have chosen
print("")
print("The next page if any: ",results["tracks"]["next"]) #link to the next page (next 50 tracks)
print("")
print("The starting webpage: ",results["tracks"]["offset"]) # Actual offset (starting point)
print("")
print("Starting webpage: ",results["tracks"]["previous"]) #Previous search
print("")
print("Total number of results: ",results["tracks"]["total"]) # Number of matches
# Out:
# The json file has the following keys:  ['tracks']
#
# The 'tracks' key has the following child keys:  ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
#
# The query we made is:  https://api.spotify.com/v1/search?query=Flesh+World&type=track&market=GB&offset=0&limit=1
#
# The song's info is contained in:  [{'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3OoNpyvA82LedOZWG3WE8Z'}, 'href': 'https://api.spotify.com/v1/artists/3OoNpyvA82LedOZWG3WE8Z', 'id': '3OoNpyvA82LedOZWG3WE8Z', 'name': 'Coeo', 'type': 'artist', 'uri': 'spotify:artist:3OoNpyvA82LedOZWG3WE8Z'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/6h9jdXMrcq8fMeRVgjqapc'}, 'href': 'https://api.spotify.com/v1/albums/6h9jdXMrcq8fMeRVgjqapc', 'id': '6h9jdXMrcq8fMeRVgjqapc', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273344cfda5f334e81ad51aa464', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02344cfda5f334e81ad51aa464', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851344cfda5f334e81ad51aa464', 'width': 64}], 'name': 'Flesh World', 'release_date': '2017-10-06', 'release_date_precision': 'day', 'total_tracks': 3, 'type': 'album', 'uri': 'spotify:album:6h9jdXMrcq8fMeRVgjqapc'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3OoNpyvA82LedOZWG3WE8Z'}, 'href': 'https://api.spotify.com/v1/artists/3OoNpyvA82LedOZWG3WE8Z', 'id': '3OoNpyvA82LedOZWG3WE8Z', 'name': 'Coeo', 'type': 'artist', 'uri': 'spotify:artist:3OoNpyvA82LedOZWG3WE8Z'}], 'disc_number': 1, 'duration_ms': 398139, 'explicit': False, 'external_ids': {'isrc': 'DEBY41200289'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/5ZqvrH3XyHXXJ7vvy3b9lF'}, 'href': 'https://api.spotify.com/v1/tracks/5ZqvrH3XyHXXJ7vvy3b9lF', 'id': '5ZqvrH3XyHXXJ7vvy3b9lF', 'is_local': False, 'is_playable': True, 'name': 'Flesh World', 'popularity': 35, 'preview_url': 'https://p.scdn.co/mp3-preview/16c11755be366b5c4ae65bb80286b85334a62d7a?cid=11aeab0ee6e244cea478c7b9ef6d1af0', 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:5ZqvrH3XyHXXJ7vvy3b9lF'}]
#
# The limit of the query we've made is:  1
#
# The next page if any:  https://api.spotify.com/v1/search?query=Flesh+World&type=track&market=GB&offset=1&limit=1
#
# The starting webpage:  0
#
# Starting webpage:  None
#
# Total number of results:  665

# %% [markdown]
# ### Checking the albums

# %%
print(results["tracks"]["items"][0]["album"]) # we have more info about the album
print("****************\n")
print(list(results["tracks"]["items"][0]["album"].keys())) # Will check artists, id, name, release date, total tracks 
print("****************\n")
print(results["tracks"]["items"][0]["album"]["artists"]) # List with artists and information
print("****************\n")
print("The album ID is: ",results["tracks"]["items"][0]["album"]["id"]) # Album ID 
print("****************\n")
print(results["tracks"]["items"][0]["album"]["name"]) # Album name (if its a single u'll get the name of the song)
# Out:
# {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3OoNpyvA82LedOZWG3WE8Z'}, 'href': 'https://api.spotify.com/v1/artists/3OoNpyvA82LedOZWG3WE8Z', 'id': '3OoNpyvA82LedOZWG3WE8Z', 'name': 'Coeo', 'type': 'artist', 'uri': 'spotify:artist:3OoNpyvA82LedOZWG3WE8Z'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/6h9jdXMrcq8fMeRVgjqapc'}, 'href': 'https://api.spotify.com/v1/albums/6h9jdXMrcq8fMeRVgjqapc', 'id': '6h9jdXMrcq8fMeRVgjqapc', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273344cfda5f334e81ad51aa464', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02344cfda5f334e81ad51aa464', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851344cfda5f334e81ad51aa464', 'width': 64}], 'name': 'Flesh World', 'release_date': '2017-10-06', 'release_date_precision': 'day', 'total_tracks': 3, 'type': 'album', 'uri': 'spotify:album:6h9jdXMrcq8fMeRVgjqapc'}
# ****************
#
# ['album_type', 'artists', 'external_urls', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'type', 'uri']
# ****************
#
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3OoNpyvA82LedOZWG3WE8Z'}, 'href': 'https://api.spotify.com/v1/artists/3OoNpyvA82LedOZWG3WE8Z', 'id': '3OoNpyvA82LedOZWG3WE8Z', 'name': 'Coeo', 'type': 'artist', 'uri': 'spotify:artist:3OoNpyvA82LedOZWG3WE8Z'}]
# ****************
#
# The album ID is:  6h9jdXMrcq8fMeRVgjqapc
# ****************
#
# Flesh World

# %% [markdown]
# ### Other info about the track

# %%
print(results["tracks"]["items"][0]["artists"]) # Track artists
print(results["tracks"]["items"][0]["id"]) # Track ID
print(results["tracks"]["items"][0]["name"]) # Track name
print(results["tracks"]["items"][0]["popularity"]) # Popularity index
print(results["tracks"]["items"][0]["uri"]) # Basically ID
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3OoNpyvA82LedOZWG3WE8Z'}, 'href': 'https://api.spotify.com/v1/artists/3OoNpyvA82LedOZWG3WE8Z', 'id': '3OoNpyvA82LedOZWG3WE8Z', 'name': 'Coeo', 'type': 'artist', 'uri': 'spotify:artist:3OoNpyvA82LedOZWG3WE8Z'}]
# 5ZqvrH3XyHXXJ7vvy3b9lF
# Flesh World
# 35
# spotify:track:5ZqvrH3XyHXXJ7vvy3b9lF

# %% [markdown]
# ## Getting the audio features of a song

# %%
sp.audio_features(song["tracks"]["items"][0]["id"] )
# Out:
# [{'danceability': 0.788,
#   'energy': 0.44,
#   'key': 2,
#   'loudness': -10.085,
#   'mode': 0,
#   'speechiness': 0.0518,
#   'acousticness': 0.0811,
#   'instrumentalness': 0.922,
#   'liveness': 0.129,
#   'valence': 0.753,
#   'tempo': 117.015,
#   'type': 'audio_features',
#   'id': '5ZqvrH3XyHXXJ7vvy3b9lF',
#   'uri': 'spotify:track:5ZqvrH3XyHXXJ7vvy3b9lF',
#   'track_href': 'https://api.spotify.com/v1/tracks/5ZqvrH3XyHXXJ7vvy3b9lF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5ZqvrH3XyHXXJ7vvy3b9lF',
#   'duration_ms': 398139,
#   'time_signature': 4}]

# %%
list_of_songs=[]
for index in range(0,len(song["tracks"]["items"])):
    list_of_songs.append(sp.audio_features(song["tracks"]["items"][index]["uri"])[0])
pd.DataFrame(list_of_songs)
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.788   0.440    2   -10.085     0       0.0518      0.081100
# 1         0.615   0.789    6    -4.877     0       0.0370      0.000017
# 2         0.518   0.714    7    -9.444     1       0.2080      0.002030
# 3         0.782   0.540    7   -10.358     1       0.0810      0.052900
# 4         0.786   0.431    2   -13.491     0       0.0555      0.098300
# 5         0.483   0.953    0    -4.302     1       0.0911      0.000490
# 6         0.406   0.750    0    -8.487     1       0.0394      0.000851
# 7         0.362   0.956    7    -5.223     0       0.0973      0.000417
# 8         0.852   0.432    9    -9.966     1       0.0864      0.003300
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.922000    0.1290    0.753  117.015  audio_features
# 1          0.000003    0.1680    0.353  130.044  audio_features
# 2          0.000007    0.1320    0.496   87.283  audio_features
# 3          0.485000    0.3310    0.625  117.023  audio_features
# 4          0.854000    0.0959    0.722  120.005  audio_features
# 5          0.000454    0.1570    0.574  174.108  audio_features
# 6          0.000015    0.1440    0.102  100.046  audio_features
# 7          0.000789    0.0825    0.313  125.992  audio_features
# 8          0.866000    0.0730    0.442  115.975  audio_features
#
#                        id                                   uri  \
# 0  5ZqvrH3XyHXXJ7vvy3b9lF  spotify:track:5ZqvrH3XyHXXJ7vvy3b9lF
# 1  1i2gMeXwREbvnJe6Uh8w6A  spotify:track:1i2gMeXwREbvnJe6Uh8w6A
# 2  3xKVUJjEOdR8ncs0RrWlzU  spotify:track:3xKVUJjEOdR8ncs0RrWlzU
# 3  5P3iHoGYKwPIdvBec1Py36  spotify:track:5P3iHoGYKwPIdvBec1Py36
# 4  3p8sSQ01EWfuGeNpy6SAmb  spotify:track:3p8sSQ01EWfuGeNpy6SAmb
# 5  4Mp8P2pDUV7B2PwLSWW1pz  spotify:track:4Mp8P2pDUV7B2PwLSWW1pz
# 6  0LBwpoUs3Hy7158PjAeN3i  spotify:track:0LBwpoUs3Hy7158PjAeN3i
# 7  18kKRFSgq9pv5cpuXqC0Vq  spotify:track:18kKRFSgq9pv5cpuXqC0Vq
# 8  5MXIYhseXGWR3oE8PORqoP  spotify:track:5MXIYhseXGWR3oE8PORqoP
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/5ZqvrH3XyHXX...
# 1  https://api.spotify.com/v1/tracks/1i2gMeXwREbv...
# 2  https://api.spotify.com/v1/tracks/3xKVUJjEOdR8...
# 3  https://api.spotify.com/v1/tracks/5P3iHoGYKwPI...
# 4  https://api.spotify.com/v1/tracks/3p8sSQ01EWfu...
# 5  https://api.spotify.com/v1/tracks/4Mp8P2pDUV7B...
# 6  https://api.spotify.com/v1/tracks/0LBwpoUs3Hy7...
# 7  https://api.spotify.com/v1/tracks/18kKRFSgq9pv...
# 8  https://api.spotify.com/v1/tracks/5MXIYhseXGWR...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/5Zqv...       398139
# 1  https://api.spotify.com/v1/audio-analysis/1i2g...       234493
# 2  https://api.spotify.com/v1/audio-analysis/3xKV...       204453
# 3  https://api.spotify.com/v1/audio-analysis/5P3i...       599247
# 4  https://api.spotify.com/v1/audio-analysis/3p8s...       351913
# 5  https://api.spotify.com/v1/audio-analysis/4Mp8...       215307
# 6  https://api.spotify.com/v1/audio-analysis/0LBw...       343288
# 7  https://api.spotify.com/v1/audio-analysis/18kK...       371187
# 8  https://api.spotify.com/v1/audio-analysis/5MXI...       430880
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
# 5               4
# 6               4
# 7               4
# 8               4

# %%
sp.audio_features(song["tracks"]["items"][index]["uri"])
# Out:
# [{'danceability': 0.852,
#   'energy': 0.432,
#   'key': 9,
#   'loudness': -9.966,
#   'mode': 1,
#   'speechiness': 0.0864,
#   'acousticness': 0.0033,
#   'instrumentalness': 0.866,
#   'liveness': 0.073,
#   'valence': 0.442,
#   'tempo': 115.975,
#   'type': 'audio_features',
#   'id': '5MXIYhseXGWR3oE8PORqoP',
#   'uri': 'spotify:track:5MXIYhseXGWR3oE8PORqoP',
#   'track_href': 'https://api.spotify.com/v1/tracks/5MXIYhseXGWR3oE8PORqoP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5MXIYhseXGWR3oE8PORqoP',
#   'duration_ms': 430880,
#   'time_signature': 4}]

# %% [markdown]
# ##  Searching a playlist

# %%
playlist = sp.user_playlist_tracks("spotify","2Uh5VseH92384vmM5SMUgA", market="GB")
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/2Uh5VseH92384vmM5SMUgA/tracks?offset=0&limit=100&market=GB&additional_types=track',
#  'items': [{'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#        'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#        'id': '1yxSLGMDHlW21z4YXirZDS',
#        'name': 'Black Eyed Peas',
#        'type': 'artist',
#        'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2Yx0X8CYJD0G2pvJYZcTxt'},
#      'href': 'https://api.spotify.com/v1/albums/2Yx0X8CYJD0G2pvJYZcTxt',
#      'id': '2Yx0X8CYJD0G2pvJYZcTxt',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273758ecff064882ebbf6407f3f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02758ecff064882ebbf6407f3f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851758ecff064882ebbf6407f3f',
#        'width': 64}],
#      'name': 'Elephunk',
#      'release_date': '2003-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:2Yx0X8CYJD0G2pvJYZcTxt'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#       'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#       'id': '1yxSLGMDHlW21z4YXirZDS',
#       'name': 'Black Eyed Peas',
#       'type': 'artist',
#       'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#     'disc_number': 1,
#     'duration_ms': 215920,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USIR10311893'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0AnSLxClEuLksOSiIYHm4G'},
#     'href': 'https://api.spotify.com/v1/tracks/0AnSLxClEuLksOSiIYHm4G',
#     'id': '0AnSLxClEuLksOSiIYHm4G',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/3yI8UscZa7l6tADw4NsBCA'},
#      'href': 'https://api.spotify.com/v1/tracks/3yI8UscZa7l6tADw4NsBCA',
#      'id': '3yI8UscZa7l6tADw4NsBCA',
#      'type': 'track',
#      'uri': 'spotify:track:3yI8UscZa7l6tADw4NsBCA'},
#     'name': "Let's Get Retarded",
#     'popularity': 45,
#     'preview_url': None,
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:0AnSLxClEuLksOSiIYHm4G'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#        'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#        'id': '1yxSLGMDHlW21z4YXirZDS',
#        'name': 'Black Eyed Peas',
#        'type': 'artist',
#        'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2Yx0X8CYJD0G2pvJYZcTxt'},
#      'href': 'https://api.spotify.com/v1/albums/2Yx0X8CYJD0G2pvJYZcTxt',
#      'id': '2Yx0X8CYJD0G2pvJYZcTxt',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273758ecff064882ebbf6407f3f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02758ecff064882ebbf6407f3f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851758ecff064882ebbf6407f3f',
#        'width': 64}],
#      'name': 'Elephunk',
#      'release_date': '2003-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:2Yx0X8CYJD0G2pvJYZcTxt'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#       'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#       'id': '1yxSLGMDHlW21z4YXirZDS',
#       'name': 'Black Eyed Peas',
#       'type': 'artist',
#       'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#     'disc_number': 1,
#     'duration_ms': 296186,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USIR10311895'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1HWsZxKLgySrtXOi3a5Q0j'},
#     'href': 'https://api.spotify.com/v1/tracks/1HWsZxKLgySrtXOi3a5Q0j',
#     'id': '1HWsZxKLgySrtXOi3a5Q0j',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/5HJTlCbUnp1G5lMrlrlBSI'},
#      'href': 'https://api.spotify.com/v1/tracks/5HJTlCbUnp1G5lMrlrlBSI',
#      'id': '5HJTlCbUnp1G5lMrlrlBSI',
#      'type': 'track',
#      'uri': 'spotify:track:5HJTlCbUnp1G5lMrlrlBSI'},
#     'name': 'Shut Up',
#     'popularity': 49,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:1HWsZxKLgySrtXOi3a5Q0j'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#        'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#        'id': '1yxSLGMDHlW21z4YXirZDS',
#        'name': 'Black Eyed Peas',
#        'type': 'artist',
#        'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6VsJamdhvYKcnpwHAKULI0'},
#      'href': 'https://api.spotify.com/v1/albums/6VsJamdhvYKcnpwHAKULI0',
#      'id': '6VsJamdhvYKcnpwHAKULI0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c6710b4a52539506c30e5354',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c6710b4a52539506c30e5354',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c6710b4a52539506c30e5354',
#        'width': 64}],
#      'name': 'Monkey Business',
#      'release_date': '2005-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:6VsJamdhvYKcnpwHAKULI0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#       'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#       'id': '1yxSLGMDHlW21z4YXirZDS',
#       'name': 'Black Eyed Peas',
#       'type': 'artist',
#       'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#     'disc_number': 1,
#     'duration_ms': 213066,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USIR10500407'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2ygMBIctKIAfbEBcT9065L'},
#     'href': 'https://api.spotify.com/v1/tracks/2ygMBIctKIAfbEBcT9065L',
#     'id': '2ygMBIctKIAfbEBcT9065L',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/7KIbDUwumrpG5f30kEYW1v'},
#      'href': 'https://api.spotify.com/v1/tracks/7KIbDUwumrpG5f30kEYW1v',
#      'id': '7KIbDUwumrpG5f30kEYW1v',
#      'type': 'track',
#      'uri': 'spotify:track:7KIbDUwumrpG5f30kEYW1v'},
#     'name': 'Pump It',
#     'popularity': 78,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2ygMBIctKIAfbEBcT9065L'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#        'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#        'id': '1yxSLGMDHlW21z4YXirZDS',
#        'name': 'Black Eyed Peas',
#        'type': 'artist',
#        'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6VsJamdhvYKcnpwHAKULI0'},
#      'href': 'https://api.spotify.com/v1/albums/6VsJamdhvYKcnpwHAKULI0',
#      'id': '6VsJamdhvYKcnpwHAKULI0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c6710b4a52539506c30e5354',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c6710b4a52539506c30e5354',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c6710b4a52539506c30e5354',
#        'width': 64}],
#      'name': 'Monkey Business',
#      'release_date': '2005-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:6VsJamdhvYKcnpwHAKULI0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#       'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#       'id': '1yxSLGMDHlW21z4YXirZDS',
#       'name': 'Black Eyed Peas',
#       'type': 'artist',
#       'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#     'disc_number': 1,
#     'duration_ms': 326960,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USIR10500771'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/20jYtEun4dUdYZ9foaOC48'},
#     'href': 'https://api.spotify.com/v1/tracks/20jYtEun4dUdYZ9foaOC48',
#     'id': '20jYtEun4dUdYZ9foaOC48',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2WNVqZq1ujhMDlOAqBFkVv'},
#      'href': 'https://api.spotify.com/v1/tracks/2WNVqZq1ujhMDlOAqBFkVv',
#      'id': '2WNVqZq1ujhMDlOAqBFkVv',
#      'type': 'track',
#      'uri': 'spotify:track:2WNVqZq1ujhMDlOAqBFkVv'},
#     'name': 'My Humps',
#     'popularity': 71,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:20jYtEun4dUdYZ9foaOC48'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#        'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#        'id': '26dSoYclwsYLMAKD3tpOr4',
#        'name': 'Britney Spears',
#        'type': 'artist',
#        'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3caKTh2tJMowPiMz0cguLI'},
#      'href': 'https://api.spotify.com/v1/albums/3caKTh2tJMowPiMz0cguLI',
#      'id': '3caKTh2tJMowPiMz0cguLI',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27338a33970ad21a2a1d1315875',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0238a33970ad21a2a1d1315875',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485138a33970ad21a2a1d1315875',
#        'width': 64}],
#      'name': 'Greatest Hits: My Prerogative',
#      'release_date': '2004-11-08',
#      'release_date_precision': 'day',
#      'total_tracks': 27,
#      'type': 'album',
#      'uri': 'spotify:album:3caKTh2tJMowPiMz0cguLI'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#       'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#       'id': '26dSoYclwsYLMAKD3tpOr4',
#       'name': 'Britney Spears',
#       'type': 'artist',
#       'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#     'disc_number': 1,
#     'duration_ms': 198813,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI10301005'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/26nr9XnFCYWxBTIP7HyWXg'},
#     'href': 'https://api.spotify.com/v1/tracks/26nr9XnFCYWxBTIP7HyWXg',
#     'id': '26nr9XnFCYWxBTIP7HyWXg',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Toxic',
#     'popularity': 55,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4bad1a2973681814b27247b1b8fa44c69c413040?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:26nr9XnFCYWxBTIP7HyWXg'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#        'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#        'id': '26dSoYclwsYLMAKD3tpOr4',
#        'name': 'Britney Spears',
#        'type': 'artist',
#        'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1ePkYcH5ZQCb1b4tQeiEDj'},
#      'href': 'https://api.spotify.com/v1/albums/1ePkYcH5ZQCb1b4tQeiEDj',
#      'id': '1ePkYcH5ZQCb1b4tQeiEDj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ca10fae7d292c52f7e8b11ca',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ca10fae7d292c52f7e8b11ca',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ca10fae7d292c52f7e8b11ca',
#        'width': 64}],
#      'name': 'Blackout',
#      'release_date': '2007-10-25',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:1ePkYcH5ZQCb1b4tQeiEDj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#       'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#       'id': '26dSoYclwsYLMAKD3tpOr4',
#       'name': 'Britney Spears',
#       'type': 'artist',
#       'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#     'disc_number': 1,
#     'duration_ms': 251240,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI10700609'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6ic8OlLUNEATToEFU3xmaH'},
#     'href': 'https://api.spotify.com/v1/tracks/6ic8OlLUNEATToEFU3xmaH',
#     'id': '6ic8OlLUNEATToEFU3xmaH',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Gimme More',
#     'popularity': 83,
#     'preview_url': 'https://p.scdn.co/mp3-preview/933d11a18d0ec4884f4a9620f4d628a7295e8faf?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6ic8OlLUNEATToEFU3xmaH'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#        'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#        'id': '26dSoYclwsYLMAKD3tpOr4',
#        'name': 'Britney Spears',
#        'type': 'artist',
#        'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1ePkYcH5ZQCb1b4tQeiEDj'},
#      'href': 'https://api.spotify.com/v1/albums/1ePkYcH5ZQCb1b4tQeiEDj',
#      'id': '1ePkYcH5ZQCb1b4tQeiEDj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ca10fae7d292c52f7e8b11ca',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ca10fae7d292c52f7e8b11ca',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ca10fae7d292c52f7e8b11ca',
#        'width': 64}],
#      'name': 'Blackout',
#      'release_date': '2007-10-25',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:1ePkYcH5ZQCb1b4tQeiEDj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#       'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#       'id': '26dSoYclwsYLMAKD3tpOr4',
#       'name': 'Britney Spears',
#       'type': 'artist',
#       'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#     'disc_number': 1,
#     'duration_ms': 175466,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI10700734'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5X9tIJkTHxB19SK3FtnHT5'},
#     'href': 'https://api.spotify.com/v1/tracks/5X9tIJkTHxB19SK3FtnHT5',
#     'id': '5X9tIJkTHxB19SK3FtnHT5',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Freakshow',
#     'popularity': 49,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e61ec46bc5932d79c4ea219177ba571d633d2246?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#     'track': True,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:5X9tIJkTHxB19SK3FtnHT5'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#        'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#        'id': '26dSoYclwsYLMAKD3tpOr4',
#        'name': 'Britney Spears',
#        'type': 'artist',
#        'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1ePkYcH5ZQCb1b4tQeiEDj'},
#      'href': 'https://api.spotify.com/v1/albums/1ePkYcH5ZQCb1b4tQeiEDj',
#      'id': '1ePkYcH5ZQCb1b4tQeiEDj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ca10fae7d292c52f7e8b11ca',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ca10fae7d292c52f7e8b11ca',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ca10fae7d292c52f7e8b11ca',
#        'width': 64}],
#      'name': 'Blackout',
#      'release_date': '2007-10-25',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:1ePkYcH5ZQCb1b4tQeiEDj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#       'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#       'id': '26dSoYclwsYLMAKD3tpOr4',
#       'name': 'Britney Spears',
#       'type': 'artist',
#       'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#     'disc_number': 1,
#     'duration_ms': 212106,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI10700729'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2EvwLVrnYbCZEG6Kx5DCRy'},
#     'href': 'https://api.spotify.com/v1/tracks/2EvwLVrnYbCZEG6Kx5DCRy',
#     'id': '2EvwLVrnYbCZEG6Kx5DCRy',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Piece of Me',
#     'popularity': 68,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2ece5b2602fdaa7a69643e8729d96ae9c73b19a8?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:2EvwLVrnYbCZEG6Kx5DCRy'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#        'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#        'id': '26dSoYclwsYLMAKD3tpOr4',
#        'name': 'Britney Spears',
#        'type': 'artist',
#        'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2tve5DGwub1TtbX1khPX5j'},
#      'href': 'https://api.spotify.com/v1/albums/2tve5DGwub1TtbX1khPX5j',
#      'id': '2tve5DGwub1TtbX1khPX5j',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27354c6edd554935d73e159e199',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0254c6edd554935d73e159e199',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485154c6edd554935d73e159e199',
#        'width': 64}],
#      'name': 'Circus (Deluxe Version)',
#      'release_date': '2008-12-02',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:2tve5DGwub1TtbX1khPX5j'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#       'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#       'id': '26dSoYclwsYLMAKD3tpOr4',
#       'name': 'Britney Spears',
#       'type': 'artist',
#       'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#     'disc_number': 1,
#     'duration_ms': 224400,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI10800838'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4fixebDZAVToLbUCuEloa2'},
#     'href': 'https://api.spotify.com/v1/tracks/4fixebDZAVToLbUCuEloa2',
#     'id': '4fixebDZAVToLbUCuEloa2',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Womanizer',
#     'popularity': 79,
#     'preview_url': 'https://p.scdn.co/mp3-preview/40c87bb00fe6bab71f758643b2d1e598c5374410?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4fixebDZAVToLbUCuEloa2'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#        'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#        'id': '26dSoYclwsYLMAKD3tpOr4',
#        'name': 'Britney Spears',
#        'type': 'artist',
#        'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3WNxdumkSMGMJRhEgK80qx'},
#      'href': 'https://api.spotify.com/v1/albums/3WNxdumkSMGMJRhEgK80qx',
#      'id': '3WNxdumkSMGMJRhEgK80qx',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738e49866860c25afffe2f1a02',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028e49866860c25afffe2f1a02',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518e49866860c25afffe2f1a02',
#        'width': 64}],
#      'name': '...Baby One More Time (Digital Deluxe Version)',
#      'release_date': '1999-01-12',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:3WNxdumkSMGMJRhEgK80qx'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#       'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#       'id': '26dSoYclwsYLMAKD3tpOr4',
#       'name': 'Britney Spears',
#       'type': 'artist',
#       'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#     'disc_number': 1,
#     'duration_ms': 245066,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI19910452'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1UI0l2L66HJ9AtoEOlHzv4'},
#     'href': 'https://api.spotify.com/v1/tracks/1UI0l2L66HJ9AtoEOlHzv4',
#     'id': '1UI0l2L66HJ9AtoEOlHzv4',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Sometimes',
#     'popularity': 70,
#     'preview_url': 'https://p.scdn.co/mp3-preview/66534231ccdd99619485b6ea4fa90987322dd812?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:1UI0l2L66HJ9AtoEOlHzv4'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#        'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#        'id': '26dSoYclwsYLMAKD3tpOr4',
#        'name': 'Britney Spears',
#        'type': 'artist',
#        'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5PmgtkodFl2Om3hMXONDll'},
#      'href': 'https://api.spotify.com/v1/albums/5PmgtkodFl2Om3hMXONDll',
#      'id': '5PmgtkodFl2Om3hMXONDll',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732aa20611c7fb964a74ab01a6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022aa20611c7fb964a74ab01a6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512aa20611c7fb964a74ab01a6',
#        'width': 64}],
#      'name': 'Oops!... I Did It Again',
#      'release_date': '2000-05-16',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:5PmgtkodFl2Om3hMXONDll'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#       'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#       'id': '26dSoYclwsYLMAKD3tpOr4',
#       'name': 'Britney Spears',
#       'type': 'artist',
#       'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#     'disc_number': 1,
#     'duration_ms': 211160,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI10000100'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6naxalmIoLFWR0siv8dnQQ'},
#     'href': 'https://api.spotify.com/v1/tracks/6naxalmIoLFWR0siv8dnQQ',
#     'id': '6naxalmIoLFWR0siv8dnQQ',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Oops!...I Did It Again',
#     'popularity': 81,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7fb86827422540ad01f65870375fef055412f034?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6naxalmIoLFWR0siv8dnQQ'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#        'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#        'id': '26dSoYclwsYLMAKD3tpOr4',
#        'name': 'Britney Spears',
#        'type': 'artist',
#        'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3WNxdumkSMGMJRhEgK80qx'},
#      'href': 'https://api.spotify.com/v1/albums/3WNxdumkSMGMJRhEgK80qx',
#      'id': '3WNxdumkSMGMJRhEgK80qx',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738e49866860c25afffe2f1a02',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028e49866860c25afffe2f1a02',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518e49866860c25afffe2f1a02',
#        'width': 64}],
#      'name': '...Baby One More Time (Digital Deluxe Version)',
#      'release_date': '1999-01-12',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:3WNxdumkSMGMJRhEgK80qx'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#       'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#       'id': '26dSoYclwsYLMAKD3tpOr4',
#       'name': 'Britney Spears',
#       'type': 'artist',
#       'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#     'disc_number': 1,
#     'duration_ms': 211066,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI19810404'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3MjUtNVVq3C8Fn0MP3zhXa'},
#     'href': 'https://api.spotify.com/v1/tracks/3MjUtNVVq3C8Fn0MP3zhXa',
#     'id': '3MjUtNVVq3C8Fn0MP3zhXa',
#     'is_local': False,
#     'is_playable': True,
#     'name': '...Baby One More Time',
#     'popularity': 81,
#     'preview_url': 'https://p.scdn.co/mp3-preview/da2134a161f1cb34d17c2d6d7e77cc93d1c1e6f7?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3MjUtNVVq3C8Fn0MP3zhXa'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#        'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#        'id': '6Ff53KvcvAj5U7Z1vojB5o',
#        'name': '*NSYNC',
#        'type': 'artist',
#        'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7K5qlneuWF1CcY6ERzwkLB'},
#      'href': 'https://api.spotify.com/v1/albums/7K5qlneuWF1CcY6ERzwkLB',
#      'id': '7K5qlneuWF1CcY6ERzwkLB',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273186b235052f031900c5cb282',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02186b235052f031900c5cb282',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851186b235052f031900c5cb282',
#        'width': 64}],
#      'name': "'N Sync UK Version",
#      'release_date': '1997',
#      'release_date_precision': 'year',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:7K5qlneuWF1CcY6ERzwkLB'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#       'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#       'id': '6Ff53KvcvAj5U7Z1vojB5o',
#       'name': '*NSYNC',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#     'disc_number': 1,
#     'duration_ms': 209400,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEA819700002'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/73q3FpQVXWk5eSUnyo83E4'},
#     'href': 'https://api.spotify.com/v1/tracks/73q3FpQVXWk5eSUnyo83E4',
#     'id': '73q3FpQVXWk5eSUnyo83E4',
#     'is_local': False,
#     'is_playable': True,
#     'name': "Tearin' up My Heart - Radio Edit",
#     'popularity': 67,
#     'preview_url': 'https://p.scdn.co/mp3-preview/cce95b757e13948b173ab4be1fa1e214660eafd2?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:73q3FpQVXWk5eSUnyo83E4'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#        'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#        'id': '6Ff53KvcvAj5U7Z1vojB5o',
#        'name': '*NSYNC',
#        'type': 'artist',
#        'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7K5qlneuWF1CcY6ERzwkLB'},
#      'href': 'https://api.spotify.com/v1/albums/7K5qlneuWF1CcY6ERzwkLB',
#      'id': '7K5qlneuWF1CcY6ERzwkLB',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273186b235052f031900c5cb282',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02186b235052f031900c5cb282',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851186b235052f031900c5cb282',
#        'width': 64}],
#      'name': "'N Sync UK Version",
#      'release_date': '1997',
#      'release_date_precision': 'year',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:7K5qlneuWF1CcY6ERzwkLB'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#       'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#       'id': '6Ff53KvcvAj5U7Z1vojB5o',
#       'name': '*NSYNC',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#     'disc_number': 1,
#     'duration_ms': 200440,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEA819600477'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/221LRlPHPuevgE1tuUlof9'},
#     'href': 'https://api.spotify.com/v1/tracks/221LRlPHPuevgE1tuUlof9',
#     'id': '221LRlPHPuevgE1tuUlof9',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'I Want You Back - Radio Edit',
#     'popularity': 62,
#     'preview_url': 'https://p.scdn.co/mp3-preview/eee3b05f721b771ce0934a9913e6d0ff83305856?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#     'track': True,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:221LRlPHPuevgE1tuUlof9'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#        'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#        'id': '6Ff53KvcvAj5U7Z1vojB5o',
#        'name': '*NSYNC',
#        'type': 'artist',
#        'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7MNoY9pyL6QnnVNeV3XfVR'},
#      'href': 'https://api.spotify.com/v1/albums/7MNoY9pyL6QnnVNeV3XfVR',
#      'id': '7MNoY9pyL6QnnVNeV3XfVR',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27377d7eb27ad62530422db5b8e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0277d7eb27ad62530422db5b8e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485177d7eb27ad62530422db5b8e',
#        'width': 64}],
#      'name': 'Greatest Hits',
#      'release_date': '2005-10-21',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:7MNoY9pyL6QnnVNeV3XfVR'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#       'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#       'id': '6Ff53KvcvAj5U7Z1vojB5o',
#       'name': '*NSYNC',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#     'disc_number': 1,
#     'duration_ms': 199640,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI10000001'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2yiZyjMEByt9sJBZWnWaDR'},
#     'href': 'https://api.spotify.com/v1/tracks/2yiZyjMEByt9sJBZWnWaDR',
#     'id': '2yiZyjMEByt9sJBZWnWaDR',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bye Bye Bye',
#     'popularity': 56,
#     'preview_url': 'https://p.scdn.co/mp3-preview/26d31ed79b698d064131a219c69aa3f795b91f01?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2yiZyjMEByt9sJBZWnWaDR'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#        'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#        'id': '6Ff53KvcvAj5U7Z1vojB5o',
#        'name': '*NSYNC',
#        'type': 'artist',
#        'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5hMd4vAfSUT1cbYCnRUako'},
#      'href': 'https://api.spotify.com/v1/albums/5hMd4vAfSUT1cbYCnRUako',
#      'id': '5hMd4vAfSUT1cbYCnRUako',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273fceb9d92981970dbeea23257',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02fceb9d92981970dbeea23257',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851fceb9d92981970dbeea23257',
#        'width': 64}],
#      'name': 'No Strings Attached',
#      'release_date': '2000-03-21',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:5hMd4vAfSUT1cbYCnRUako'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#       'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#       'id': '6Ff53KvcvAj5U7Z1vojB5o',
#       'name': '*NSYNC',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#     'disc_number': 1,
#     'duration_ms': 191040,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI10000043'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/35zGjsxI020C2NPKp2fzS7'},
#     'href': 'https://api.spotify.com/v1/tracks/35zGjsxI020C2NPKp2fzS7',
#     'id': '35zGjsxI020C2NPKp2fzS7',
#     'is_local': False,
#     'is_playable': True,
#     'name': "It's Gonna Be Me",
#     'popularity': 62,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8d77d3139230f7aa3f9d1250d3c2290af35ad73b?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:35zGjsxI020C2NPKp2fzS7'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#        'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#        'id': '6Ff53KvcvAj5U7Z1vojB5o',
#        'name': '*NSYNC',
#        'type': 'artist',
#        'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5hMd4vAfSUT1cbYCnRUako'},
#      'href': 'https://api.spotify.com/v1/albums/5hMd4vAfSUT1cbYCnRUako',
#      'id': '5hMd4vAfSUT1cbYCnRUako',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273fceb9d92981970dbeea23257',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02fceb9d92981970dbeea23257',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851fceb9d92981970dbeea23257',
#        'width': 64}],
#      'name': 'No Strings Attached',
#      'release_date': '2000-03-21',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:5hMd4vAfSUT1cbYCnRUako'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#       'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#       'id': '6Ff53KvcvAj5U7Z1vojB5o',
#       'name': '*NSYNC',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#     'disc_number': 1,
#     'duration_ms': 228973,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI10000046'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3okIKaE45eGIEgnfKYa8F2'},
#     'href': 'https://api.spotify.com/v1/tracks/3okIKaE45eGIEgnfKYa8F2',
#     'id': '3okIKaE45eGIEgnfKYa8F2',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'No Strings Attached',
#     'popularity': 38,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a12822f236003d906d13de02974d2aa32722731c?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#     'track': True,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:3okIKaE45eGIEgnfKYa8F2'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5rSXSAkZ67PYJSvpUpkOr7'},
#        'href': 'https://api.spotify.com/v1/artists/5rSXSAkZ67PYJSvpUpkOr7',
#        'id': '5rSXSAkZ67PYJSvpUpkOr7',
#        'name': 'Backstreet Boys',
#        'type': 'artist',
#        'uri': 'spotify:artist:5rSXSAkZ67PYJSvpUpkOr7'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1NslKOZobWxINFaFkLol3r'},
#      'href': 'https://api.spotify.com/v1/albums/1NslKOZobWxINFaFkLol3r',
#      'id': '1NslKOZobWxINFaFkLol3r',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c2f0d820b1113f9a243fb973',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c2f0d820b1113f9a243fb973',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c2f0d820b1113f9a243fb973',
#        'width': 64}],
#      'name': 'The Hits--Chapter One',
#      'release_date': '2001-10-23',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:1NslKOZobWxINFaFkLol3r'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5rSXSAkZ67PYJSvpUpkOr7'},
#       'href': 'https://api.spotify.com/v1/artists/5rSXSAkZ67PYJSvpUpkOr7',
#       'id': '5rSXSAkZ67PYJSvpUpkOr7',
#       'name': 'Backstreet Boys',
#       'type': 'artist',
#       'uri': 'spotify:artist:5rSXSAkZ67PYJSvpUpkOr7'}],
#     'disc_number': 1,
#     'duration_ms': 286306,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI19710084'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3tH03v5SIWaglfE3rzXzeB'},
#     'href': 'https://api.spotify.com/v1/tracks/3tH03v5SIWaglfE3rzXzeB',
#     'id': '3tH03v5SIWaglfE3rzXzeB',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/5WTxbyWTpoqhdxEN2szOnl'},
#      'href': 'https://api.spotify.com/v1/tracks/5WTxbyWTpoqhdxEN2szOnl',
#      'id': '5WTxbyWTpoqhdxEN2szOnl',
#      'type': 'track',
#      'uri': 'spotify:track:5WTxbyWTpoqhdxEN2szOnl'},
#     'name': "Everybody (Backstreet's Back) - Extended Version",
#     'popularity': 64,
# ...
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H'},
#        'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#        'id': '5pKCCKE2ajJHZ9KAiaK11H',
#        'name': 'Rihanna',
#        'type': 'artist',
#        'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4FyGpObwABjn0o8Tdp7AZz'},
#      'href': 'https://api.spotify.com/v1/albums/4FyGpObwABjn0o8Tdp7AZz',
#      'id': '4FyGpObwABjn0o8Tdp7AZz',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b21609e1a2d7c1b7ba8efae2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b21609e1a2d7c1b7ba8efae2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b21609e1a2d7c1b7ba8efae2',
#        'width': 64}],
#      'name': 'Music Of The Sun',
#      'release_date': '2005-08-29',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:4FyGpObwABjn0o8Tdp7AZz'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H'},
#       'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#       'id': '5pKCCKE2ajJHZ9KAiaK11H',
#       'name': 'Rihanna',
#       'type': 'artist',
#       'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'}],
#     'disc_number': 1,
#     'duration_ms': 246960,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USIR20500331'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4TsmezEQVSZNNPv5RJ65Ov'},
#     'href': 'https://api.spotify.com/v1/tracks/4TsmezEQVSZNNPv5RJ65Ov',
#     'id': '4TsmezEQVSZNNPv5RJ65Ov',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Pon de Replay',
#     'popularity': 80,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4TsmezEQVSZNNPv5RJ65Ov'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6S0dmVVn4udvppDhZIWxCr'},
#        'href': 'https://api.spotify.com/v1/artists/6S0dmVVn4udvppDhZIWxCr',
#        'id': '6S0dmVVn4udvppDhZIWxCr',
#        'name': 'Sean Kingston',
#        'type': 'artist',
#        'uri': 'spotify:artist:6S0dmVVn4udvppDhZIWxCr'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/71clfVkkopYLrgweVj2cow'},
#      'href': 'https://api.spotify.com/v1/albums/71clfVkkopYLrgweVj2cow',
#      'id': '71clfVkkopYLrgweVj2cow',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736a45d20e414fbc456ecea553',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026a45d20e414fbc456ecea553',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516a45d20e414fbc456ecea553',
#        'width': 64}],
#      'name': 'Beautiful Girls',
#      'release_date': '2007-07-23',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:71clfVkkopYLrgweVj2cow'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6S0dmVVn4udvppDhZIWxCr'},
#       'href': 'https://api.spotify.com/v1/artists/6S0dmVVn4udvppDhZIWxCr',
#       'id': '6S0dmVVn4udvppDhZIWxCr',
#       'name': 'Sean Kingston',
#       'type': 'artist',
#       'uri': 'spotify:artist:6S0dmVVn4udvppDhZIWxCr'}],
#     'disc_number': 1,
#     'duration_ms': 225373,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM10701781'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1hGy2eLcmC8eKx7qr1tOqx'},
#     'href': 'https://api.spotify.com/v1/tracks/1hGy2eLcmC8eKx7qr1tOqx',
#     'id': '1hGy2eLcmC8eKx7qr1tOqx',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Beautiful Girls',
#     'popularity': 81,
#     'preview_url': 'https://p.scdn.co/mp3-preview/149a2a28b7acbe31096d9f3cb4618ef08926c8b2?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1hGy2eLcmC8eKx7qr1tOqx'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0TImkz4nPqjegtVSMZnMRq'},
#        'href': 'https://api.spotify.com/v1/artists/0TImkz4nPqjegtVSMZnMRq',
#        'id': '0TImkz4nPqjegtVSMZnMRq',
#        'name': 'TLC',
#        'type': 'artist',
#        'uri': 'spotify:artist:0TImkz4nPqjegtVSMZnMRq'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1CvjjpvqVMoyprsf74bpYW'},
#      'href': 'https://api.spotify.com/v1/albums/1CvjjpvqVMoyprsf74bpYW',
#      'id': '1CvjjpvqVMoyprsf74bpYW',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27361ffafd5e31a37336531cf95',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0261ffafd5e31a37336531cf95',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485161ffafd5e31a37336531cf95',
#        'width': 64}],
#      'name': 'Fanmail',
#      'release_date': '1999-02-23',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:1CvjjpvqVMoyprsf74bpYW'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0TImkz4nPqjegtVSMZnMRq'},
#       'href': 'https://api.spotify.com/v1/artists/0TImkz4nPqjegtVSMZnMRq',
#       'id': '0TImkz4nPqjegtVSMZnMRq',
#       'name': 'TLC',
#       'type': 'artist',
#       'uri': 'spotify:artist:0TImkz4nPqjegtVSMZnMRq'}],
#     'disc_number': 1,
#     'duration_ms': 214400,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USLF29900479'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1KGi9sZVMeszgZOWivFpxs'},
#     'href': 'https://api.spotify.com/v1/tracks/1KGi9sZVMeszgZOWivFpxs',
#     'id': '1KGi9sZVMeszgZOWivFpxs',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'No Scrubs',
#     'popularity': 81,
#     'preview_url': 'https://p.scdn.co/mp3-preview/69daa711bddd8fe7aa9acf17106ca85cf1ccfa14?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:1KGi9sZVMeszgZOWivFpxs'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2gBjLmx6zQnFGQJCAQpRgw'},
#        'href': 'https://api.spotify.com/v1/artists/2gBjLmx6zQnFGQJCAQpRgw',
#        'id': '2gBjLmx6zQnFGQJCAQpRgw',
#        'name': 'Nelly',
#        'type': 'artist',
#        'uri': 'spotify:artist:2gBjLmx6zQnFGQJCAQpRgw'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1kh5XByhI0DDWV7m9kddr0'},
#      'href': 'https://api.spotify.com/v1/albums/1kh5XByhI0DDWV7m9kddr0',
#      'id': '1kh5XByhI0DDWV7m9kddr0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273367bb42d6ff622f44303bae5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02367bb42d6ff622f44303bae5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851367bb42d6ff622f44303bae5',
#        'width': 64}],
#      'name': 'Nellyville',
#      'release_date': '2002-06-25',
#      'release_date_precision': 'day',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:1kh5XByhI0DDWV7m9kddr0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2gBjLmx6zQnFGQJCAQpRgw'},
#       'href': 'https://api.spotify.com/v1/artists/2gBjLmx6zQnFGQJCAQpRgw',
#       'id': '2gBjLmx6zQnFGQJCAQpRgw',
#       'name': 'Nelly',
#       'type': 'artist',
#       'uri': 'spotify:artist:2gBjLmx6zQnFGQJCAQpRgw'}],
#     'disc_number': 1,
#     'duration_ms': 228240,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUR10200371'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5FLctoy4mpCxLJ1QPneTOV'},
#     'href': 'https://api.spotify.com/v1/tracks/5FLctoy4mpCxLJ1QPneTOV',
#     'id': '5FLctoy4mpCxLJ1QPneTOV',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/04KTF78FFg8sOHC1BADqbY'},
#      'href': 'https://api.spotify.com/v1/tracks/04KTF78FFg8sOHC1BADqbY',
#      'id': '04KTF78FFg8sOHC1BADqbY',
#      'type': 'track',
#      'uri': 'spotify:track:04KTF78FFg8sOHC1BADqbY'},
#     'name': 'Hot In Herre',
#     'popularity': 59,
#     'preview_url': None,
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:5FLctoy4mpCxLJ1QPneTOV'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2NdeV5rLm47xAvogXrYhJX'},
#        'href': 'https://api.spotify.com/v1/artists/2NdeV5rLm47xAvogXrYhJX',
#        'id': '2NdeV5rLm47xAvogXrYhJX',
#        'name': 'Ciara',
#        'type': 'artist',
#        'uri': 'spotify:artist:2NdeV5rLm47xAvogXrYhJX'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/71gUhKYZIWmmjqAHlY4Br3'},
#      'href': 'https://api.spotify.com/v1/albums/71gUhKYZIWmmjqAHlY4Br3',
#      'id': '71gUhKYZIWmmjqAHlY4Br3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c1e3659212de0f437bbf395e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c1e3659212de0f437bbf395e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c1e3659212de0f437bbf395e',
#        'width': 64}],
#      'name': 'Goodies',
#      'release_date': '2004-09-27',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:71gUhKYZIWmmjqAHlY4Br3'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2NdeV5rLm47xAvogXrYhJX'},
#       'href': 'https://api.spotify.com/v1/artists/2NdeV5rLm47xAvogXrYhJX',
#       'id': '2NdeV5rLm47xAvogXrYhJX',
#       'name': 'Ciara',
#       'type': 'artist',
#       'uri': 'spotify:artist:2NdeV5rLm47xAvogXrYhJX'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2wIVse2owClT7go1WT98tk'},
#       'href': 'https://api.spotify.com/v1/artists/2wIVse2owClT7go1WT98tk',
#       'id': '2wIVse2owClT7go1WT98tk',
#       'name': 'Missy Elliott',
#       'type': 'artist',
#       'uri': 'spotify:artist:2wIVse2owClT7go1WT98tk'}],
#     'disc_number': 1,
#     'duration_ms': 203786,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USLF20400121'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7uKcScNXuO3MWw6LowBjW1'},
#     'href': 'https://api.spotify.com/v1/tracks/7uKcScNXuO3MWw6LowBjW1',
#     'id': '7uKcScNXuO3MWw6LowBjW1',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'One, Two Step (feat. Missy Elliott)',
#     'popularity': 77,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ebc79c6e835bd18a744307d51c942a749e3ad2ca?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:7uKcScNXuO3MWw6LowBjW1'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#        'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#        'id': '5YGY8feqx7naU7z4HrwZM6',
#        'name': 'Miley Cyrus',
#        'type': 'artist',
#        'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0IuHVgAvbNDJnJepuSZ8Oz'},
#      'href': 'https://api.spotify.com/v1/albums/0IuHVgAvbNDJnJepuSZ8Oz',
#      'id': '0IuHVgAvbNDJnJepuSZ8Oz',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734ea6653890e297d53e93e3e0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024ea6653890e297d53e93e3e0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514ea6653890e297d53e93e3e0',
#        'width': 64}],
#      'name': 'The Time Of Our Lives (International Version)',
#      'release_date': '2009-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:0IuHVgAvbNDJnJepuSZ8Oz'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#       'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#       'id': '5YGY8feqx7naU7z4HrwZM6',
#       'name': 'Miley Cyrus',
#       'type': 'artist',
#       'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#     'disc_number': 1,
#     'duration_ms': 202066,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USHR10924519'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3E7dfMvvCLUddWissuqMwr'},
#     'href': 'https://api.spotify.com/v1/tracks/3E7dfMvvCLUddWissuqMwr',
#     'id': '3E7dfMvvCLUddWissuqMwr',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/5Q0Nhxo0l2bP3pNjpGJwV1'},
#      'href': 'https://api.spotify.com/v1/tracks/5Q0Nhxo0l2bP3pNjpGJwV1',
#      'id': '5Q0Nhxo0l2bP3pNjpGJwV1',
#      'type': 'track',
#      'uri': 'spotify:track:5Q0Nhxo0l2bP3pNjpGJwV1'},
#     'name': 'Party In The U.S.A.',
#     'popularity': 82,
#     'preview_url': None,
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:3E7dfMvvCLUddWissuqMwr'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/2Uh5VseH92384vmM5SMUgA/tracks?offset=100&limit=100&market=GB&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 516}

# %%
playlist.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
print(list(playlist.keys())) # Let's look at items and total:
print("Total number of songs in the playlist: ",playlist["total"]) #  Let's check items:
len(playlist["items"]) # It is limited to 100 tracks, we will have to fix it:
# Out:
# ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# Total number of songs in the playlist:  516
# 100

# %%
import pprint

pprint.pprint(playlist)
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/2Uh5VseH92384vmM5SMUgA/tracks?offset=0&limit=100&market=GB&additional_types=track',
#  'items': [{'added_at': '2016-09-09T10:44:51Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#                          'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#                          'id': '22htsfsj6ksp4hr6bal4zvboa',
#                          'type': 'user',
#                          'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#                                              'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#                                              'id': '1yxSLGMDHlW21z4YXirZDS',
#                                              'name': 'Black Eyed Peas',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/2Yx0X8CYJD0G2pvJYZcTxt'},
#                                 'href': 'https://api.spotify.com/v1/albums/2Yx0X8CYJD0G2pvJYZcTxt',
#                                 'id': '2Yx0X8CYJD0G2pvJYZcTxt',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273758ecff064882ebbf6407f3f',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02758ecff064882ebbf6407f3f',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851758ecff064882ebbf6407f3f',
#                                             'width': 64}],
#                                 'name': 'Elephunk',
#                                 'release_date': '2003-01-01',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 16,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:2Yx0X8CYJD0G2pvJYZcTxt'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#                                    'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#                                    'id': '1yxSLGMDHlW21z4YXirZDS',
#                                    'name': 'Black Eyed Peas',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#                       'disc_number': 1,
#                       'duration_ms': 215920,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USIR10311893'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/0AnSLxClEuLksOSiIYHm4G'},
#                       'href': 'https://api.spotify.com/v1/tracks/0AnSLxClEuLksOSiIYHm4G',
#                       'id': '0AnSLxClEuLksOSiIYHm4G',
#                       'is_local': False,
#                       'is_playable': True,
#                       'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/3yI8UscZa7l6tADw4NsBCA'},
#                                       'href': 'https://api.spotify.com/v1/tracks/3yI8UscZa7l6tADw4NsBCA',
#                                       'id': '3yI8UscZa7l6tADw4NsBCA',
#                                       'type': 'track',
#                                       'uri': 'spotify:track:3yI8UscZa7l6tADw4NsBCA'},
#                       'name': "Let's Get Retarded",
#                       'popularity': 45,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 3,
#                       'type': 'track',
#                       'uri': 'spotify:track:0AnSLxClEuLksOSiIYHm4G'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2016-09-09T10:44:51Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#                          'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#                          'id': '22htsfsj6ksp4hr6bal4zvboa',
#                          'type': 'user',
#                          'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#                                              'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#                                              'id': '1yxSLGMDHlW21z4YXirZDS',
#                                              'name': 'Black Eyed Peas',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/2Yx0X8CYJD0G2pvJYZcTxt'},
#                                 'href': 'https://api.spotify.com/v1/albums/2Yx0X8CYJD0G2pvJYZcTxt',
#                                 'id': '2Yx0X8CYJD0G2pvJYZcTxt',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273758ecff064882ebbf6407f3f',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02758ecff064882ebbf6407f3f',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851758ecff064882ebbf6407f3f',
#                                             'width': 64}],
#                                 'name': 'Elephunk',
#                                 'release_date': '2003-01-01',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 16,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:2Yx0X8CYJD0G2pvJYZcTxt'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#                                    'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#                                    'id': '1yxSLGMDHlW21z4YXirZDS',
#                                    'name': 'Black Eyed Peas',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#                       'disc_number': 1,
#                       'duration_ms': 296186,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USIR10311895'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/1HWsZxKLgySrtXOi3a5Q0j'},
#                       'href': 'https://api.spotify.com/v1/tracks/1HWsZxKLgySrtXOi3a5Q0j',
#                       'id': '1HWsZxKLgySrtXOi3a5Q0j',
#                       'is_local': False,
#                       'is_playable': True,
#                       'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/5HJTlCbUnp1G5lMrlrlBSI'},
#                                       'href': 'https://api.spotify.com/v1/tracks/5HJTlCbUnp1G5lMrlrlBSI',
#                                       'id': '5HJTlCbUnp1G5lMrlrlBSI',
#                                       'type': 'track',
#                                       'uri': 'spotify:track:5HJTlCbUnp1G5lMrlrlBSI'},
#                       'name': 'Shut Up',
#                       'popularity': 49,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 5,
#                       'type': 'track',
#                       'uri': 'spotify:track:1HWsZxKLgySrtXOi3a5Q0j'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2016-09-09T10:44:51Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#                          'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#                          'id': '22htsfsj6ksp4hr6bal4zvboa',
#                          'type': 'user',
#                          'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#                                              'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#                                              'id': '1yxSLGMDHlW21z4YXirZDS',
#                                              'name': 'Black Eyed Peas',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/6VsJamdhvYKcnpwHAKULI0'},
#                                 'href': 'https://api.spotify.com/v1/albums/6VsJamdhvYKcnpwHAKULI0',
#                                 'id': '6VsJamdhvYKcnpwHAKULI0',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273c6710b4a52539506c30e5354',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02c6710b4a52539506c30e5354',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851c6710b4a52539506c30e5354',
#                                             'width': 64}],
#                                 'name': 'Monkey Business',
#                                 'release_date': '2005-01-01',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 16,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:6VsJamdhvYKcnpwHAKULI0'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#                                    'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#                                    'id': '1yxSLGMDHlW21z4YXirZDS',
#                                    'name': 'Black Eyed Peas',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#                       'disc_number': 1,
#                       'duration_ms': 213066,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USIR10500407'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/2ygMBIctKIAfbEBcT9065L'},
#                       'href': 'https://api.spotify.com/v1/tracks/2ygMBIctKIAfbEBcT9065L',
#                       'id': '2ygMBIctKIAfbEBcT9065L',
#                       'is_local': False,
#                       'is_playable': True,
#                       'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/7KIbDUwumrpG5f30kEYW1v'},
#                                       'href': 'https://api.spotify.com/v1/tracks/7KIbDUwumrpG5f30kEYW1v',
#                                       'id': '7KIbDUwumrpG5f30kEYW1v',
#                                       'type': 'track',
#                                       'uri': 'spotify:track:7KIbDUwumrpG5f30kEYW1v'},
#                       'name': 'Pump It',
#                       'popularity': 78,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:2ygMBIctKIAfbEBcT9065L'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2016-09-09T10:44:51Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#                          'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#                          'id': '22htsfsj6ksp4hr6bal4zvboa',
#                          'type': 'user',
#                          'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#                                              'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#                                              'id': '1yxSLGMDHlW21z4YXirZDS',
#                                              'name': 'Black Eyed Peas',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/6VsJamdhvYKcnpwHAKULI0'},
#                                 'href': 'https://api.spotify.com/v1/albums/6VsJamdhvYKcnpwHAKULI0',
#                                 'id': '6VsJamdhvYKcnpwHAKULI0',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273c6710b4a52539506c30e5354',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02c6710b4a52539506c30e5354',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851c6710b4a52539506c30e5354',
#                                             'width': 64}],
#                                 'name': 'Monkey Business',
#                                 'release_date': '2005-01-01',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 16,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:6VsJamdhvYKcnpwHAKULI0'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#                                    'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#                                    'id': '1yxSLGMDHlW21z4YXirZDS',
#                                    'name': 'Black Eyed Peas',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#                       'disc_number': 1,
#                       'duration_ms': 326960,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USIR10500771'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/20jYtEun4dUdYZ9foaOC48'},
#                       'href': 'https://api.spotify.com/v1/tracks/20jYtEun4dUdYZ9foaOC48',
#                       'id': '20jYtEun4dUdYZ9foaOC48',
#                       'is_local': False,
#                       'is_playable': True,
#                       'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2WNVqZq1ujhMDlOAqBFkVv'},
#                                       'href': 'https://api.spotify.com/v1/tracks/2WNVqZq1ujhMDlOAqBFkVv',
#                                       'id': '2WNVqZq1ujhMDlOAqBFkVv',
#                                       'type': 'track',
#                                       'uri': 'spotify:track:2WNVqZq1ujhMDlOAqBFkVv'},
#                       'name': 'My Humps',
#                       'popularity': 71,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 5,
#                       'type': 'track',
#                       'uri': 'spotify:track:20jYtEun4dUdYZ9foaOC48'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2016-09-09T10:44:51Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#                          'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#                          'id': '22htsfsj6ksp4hr6bal4zvboa',
#                          'type': 'user',
#                          'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'compilation',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#                                              'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#                                              'id': '26dSoYclwsYLMAKD3tpOr4',
#                                              'name': 'Britney Spears',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/3caKTh2tJMowPiMz0cguLI'},
#                                 'href': 'https://api.spotify.com/v1/albums/3caKTh2tJMowPiMz0cguLI',
#                                 'id': '3caKTh2tJMowPiMz0cguLI',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b27338a33970ad21a2a1d1315875',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e0238a33970ad21a2a1d1315875',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000485138a33970ad21a2a1d1315875',
#                                             'width': 64}],
#                                 'name': 'Greatest Hits: My Prerogative',
#                                 'release_date': '2004-11-08',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 27,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:3caKTh2tJMowPiMz0cguLI'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#                                    'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#                                    'id': '26dSoYclwsYLMAKD3tpOr4',
#                                    'name': 'Britney Spears',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#                       'disc_number': 1,
#                       'duration_ms': 198813,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USJI10301005'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/26nr9XnFCYWxBTIP7HyWXg'},
#                       'href': 'https://api.spotify.com/v1/tracks/26nr9XnFCYWxBTIP7HyWXg',
#                       'id': '26nr9XnFCYWxBTIP7HyWXg',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Toxic',
#                       'popularity': 55,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/4bad1a2973681814b27247b1b8fa44c69c413040?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#                       'track': True,
#                       'track_number': 2,
#                       'type': 'track',
#                       'uri': 'spotify:track:26nr9XnFCYWxBTIP7HyWXg'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2016-09-09T10:44:51Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#                          'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#                          'id': '22htsfsj6ksp4hr6bal4zvboa',
#                          'type': 'user',
#                          'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#                                              'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#                                              'id': '26dSoYclwsYLMAKD3tpOr4',
#                                              'name': 'Britney Spears',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/1ePkYcH5ZQCb1b4tQeiEDj'},
#                                 'href': 'https://api.spotify.com/v1/albums/1ePkYcH5ZQCb1b4tQeiEDj',
#                                 'id': '1ePkYcH5ZQCb1b4tQeiEDj',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273ca10fae7d292c52f7e8b11ca',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02ca10fae7d292c52f7e8b11ca',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851ca10fae7d292c52f7e8b11ca',
#                                             'width': 64}],
#                                 'name': 'Blackout',
#                                 'release_date': '2007-10-25',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 15,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:1ePkYcH5ZQCb1b4tQeiEDj'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#                                    'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#                                    'id': '26dSoYclwsYLMAKD3tpOr4',
#                                    'name': 'Britney Spears',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#                       'disc_number': 1,
#                       'duration_ms': 251240,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USJI10700609'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/6ic8OlLUNEATToEFU3xmaH'},
#                       'href': 'https://api.spotify.com/v1/tracks/6ic8OlLUNEATToEFU3xmaH',
#                       'id': '6ic8OlLUNEATToEFU3xmaH',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Gimme More',
#                       'popularity': 83,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/933d11a18d0ec4884f4a9620f4d628a7295e8faf?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:6ic8OlLUNEATToEFU3xmaH'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2016-09-09T10:44:51Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#                          'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#                          'id': '22htsfsj6ksp4hr6bal4zvboa',
#                          'type': 'user',
#                          'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#                                              'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#                                              'id': '26dSoYclwsYLMAKD3tpOr4',
#                                              'name': 'Britney Spears',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/1ePkYcH5ZQCb1b4tQeiEDj'},
#                                 'href': 'https://api.spotify.com/v1/albums/1ePkYcH5ZQCb1b4tQeiEDj',
#                                 'id': '1ePkYcH5ZQCb1b4tQeiEDj',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273ca10fae7d292c52f7e8b11ca',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02ca10fae7d292c52f7e8b11ca',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851ca10fae7d292c52f7e8b11ca',
#                                             'width': 64}],
#                                 'name': 'Blackout',
#                                 'release_date': '2007-10-25',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 15,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:1ePkYcH5ZQCb1b4tQeiEDj'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#                                    'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#                                    'id': '26dSoYclwsYLMAKD3tpOr4',
#                                    'name': 'Britney Spears',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#                       'disc_number': 1,
#                       'duration_ms': 175466,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USJI10700734'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/5X9tIJkTHxB19SK3FtnHT5'},
#                       'href': 'https://api.spotify.com/v1/tracks/5X9tIJkTHxB19SK3FtnHT5',
#                       'id': '5X9tIJkTHxB19SK3FtnHT5',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Freakshow',
#                       'popularity': 49,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/e61ec46bc5932d79c4ea219177ba571d633d2246?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#                       'track': True,
#                       'track_number': 7,
#                       'type': 'track',
#                       'uri': 'spotify:track:5X9tIJkTHxB19SK3FtnHT5'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2016-09-09T10:44:51Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#                          'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#                          'id': '22htsfsj6ksp4hr6bal4zvboa',
#                          'type': 'user',
#                          'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#                                              'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#                                              'id': '26dSoYclwsYLMAKD3tpOr4',
#                                              'name': 'Britney Spears',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/1ePkYcH5ZQCb1b4tQeiEDj'},
#                                 'href': 'https://api.spotify.com/v1/albums/1ePkYcH5ZQCb1b4tQeiEDj',
#                                 'id': '1ePkYcH5ZQCb1b4tQeiEDj',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273ca10fae7d292c52f7e8b11ca',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02ca10fae7d292c52f7e8b11ca',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851ca10fae7d292c52f7e8b11ca',
#                                             'width': 64}],
#                                 'name': 'Blackout',
#                                 'release_date': '2007-10-25',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 15,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:1ePkYcH5ZQCb1b4tQeiEDj'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#                                    'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#                                    'id': '26dSoYclwsYLMAKD3tpOr4',
#                                    'name': 'Britney Spears',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#                       'disc_number': 1,
#                       'duration_ms': 212106,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USJI10700729'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/2EvwLVrnYbCZEG6Kx5DCRy'},
#                       'href': 'https://api.spotify.com/v1/tracks/2EvwLVrnYbCZEG6Kx5DCRy',
#                       'id': '2EvwLVrnYbCZEG6Kx5DCRy',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Piece of Me',
#                       'popularity': 68,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/2ece5b2602fdaa7a69643e8729d96ae9c73b19a8?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#                       'track': True,
#                       'track_number': 2,
#                       'type': 'track',
#                       'uri': 'spotify:track:2EvwLVrnYbCZEG6Kx5DCRy'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2016-09-09T10:44:51Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#                          'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#                          'id': '22htsfsj6ksp4hr6bal4zvboa',
#                          'type': 'user',
#                          'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#                                              'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#                                              'id': '26dSoYclwsYLMAKD3tpOr4',
#                                              'name': 'Britney Spears',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/2tve5DGwub1TtbX1khPX5j'},
#                                 'href': 'https://api.spotify.com/v1/albums/2tve5DGwub1TtbX1khPX5j',
#                                 'id': '2tve5DGwub1TtbX1khPX5j',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b27354c6edd554935d73e159e199',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e0254c6edd554935d73e159e199',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000485154c6edd554935d73e159e199',
#                                             'width': 64}],
#                                 'name': 'Circus (Deluxe Version)',
#                                 'release_date': '2008-12-02',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 15,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:2tve5DGwub1TtbX1khPX5j'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#                                    'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#                                    'id': '26dSoYclwsYLMAKD3tpOr4',
#                                    'name': 'Britney Spears',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#                       'disc_number': 1,
#                       'duration_ms': 224400,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USJI10800838'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/4fixebDZAVToLbUCuEloa2'},
#                       'href': 'https://api.spotify.com/v1/tracks/4fixebDZAVToLbUCuEloa2',
#                       'id': '4fixebDZAVToLbUCuEloa2',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Womanizer',
#                       'popularity': 79,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/40c87bb00fe6bab71f758643b2d1e598c5374410?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:4fixebDZAVToLbUCuEloa2'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2016-09-09T10:44:51Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#                          'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#                          'id': '22htsfsj6ksp4hr6bal4zvboa',
#                          'type': 'user',
#                          'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#                                              'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#                                              'id': '26dSoYclwsYLMAKD3tpOr4',
#                                              'name': 'Britney Spears',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/3WNxdumkSMGMJRhEgK80qx'},
#                                 'href': 'https://api.spotify.com/v1/albums/3WNxdumkSMGMJRhEgK80qx',
#                                 'id': '3WNxdumkSMGMJRhEgK80qx',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2738e49866860c25afffe2f1a02',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e028e49866860c25afffe2f1a02',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048518e49866860c25afffe2f1a02',
#                                             'width': 64}],
#                                 'name': '...Baby One More Time (Digital Deluxe '
#                                         'Version)',
#                                 'release_date': '1999-01-12',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 16,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:3WNxdumkSMGMJRhEgK80qx'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#                                    'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#                                    'id': '26dSoYclwsYLMAKD3tpOr4',
#                                    'name': 'Britney Spears',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#                       'disc_number': 1,
#                       'duration_ms': 245066,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USJI19910452'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/1UI0l2L66HJ9AtoEOlHzv4'},
#                       'href': 'https://api.spotify.com/v1/tracks/1UI0l2L66HJ9AtoEOlHzv4',
#                       'id': '1UI0l2L66HJ9AtoEOlHzv4',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Sometimes',
#                       'popularity': 70,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/66534231ccdd99619485b6ea4fa90987322dd812?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#                       'track': True,
#                       'track_number': 3,
#                       'type': 'track',
#                       'uri': 'spotify:track:1UI0l2L66HJ9AtoEOlHzv4'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2016-09-09T10:44:51Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#                          'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#                          'id': '22htsfsj6ksp4hr6bal4zvboa',
#                          'type': 'user',
#                          'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#                                              'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#                                              'id': '26dSoYclwsYLMAKD3tpOr4',
#                                              'name': 'Britney Spears',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/5PmgtkodFl2Om3hMXONDll'},
#                                 'href': 'https://api.spotify.com/v1/albums/5PmgtkodFl2Om3hMXONDll',
#                                 'id': '5PmgtkodFl2Om3hMXONDll',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2732aa20611c7fb964a74ab01a6',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e022aa20611c7fb964a74ab01a6',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048512aa20611c7fb964a74ab01a6',
#                                             'width': 64}],
#                                 'name': 'Oops!... I Did It Again',
#                                 'release_date': '2000-05-16',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 12,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:5PmgtkodFl2Om3hMXONDll'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#                                    'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#                                    'id': '26dSoYclwsYLMAKD3tpOr4',
#                                    'name': 'Britney Spears',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#                       'disc_number': 1,
#                       'duration_ms': 211160,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USJI10000100'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/6naxalmIoLFWR0siv8dnQQ'},
#                       'href': 'https://api.spotify.com/v1/tracks/6naxalmIoLFWR0siv8dnQQ',
#                       'id': '6naxalmIoLFWR0siv8dnQQ',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Oops!...I Did It Again',
#                       'popularity': 81,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/7fb86827422540ad01f65870375fef055412f034?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:6naxalmIoLFWR0siv8dnQQ'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2016-09-09T10:44:51Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#                          'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#                          'id': '22htsfsj6ksp4hr6bal4zvboa',
#                          'type': 'user',
#                          'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#                                              'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#                                              'id': '26dSoYclwsYLMAKD3tpOr4',
#                                              'name': 'Britney Spears',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/3WNxdumkSMGMJRhEgK80qx'},
#                                 'href': 'https://api.spotify.com/v1/albums/3WNxdumkSMGMJRhEgK80qx',
#                                 'id': '3WNxdumkSMGMJRhEgK80qx',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2738e49866860c25afffe2f1a02',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e028e49866860c25afffe2f1a02',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048518e49866860c25afffe2f1a02',
#                                             'width': 64}],
#                                 'name': '...Baby One More Time (Digital Deluxe '
#                                         'Version)',
#                                 'release_date': '1999-01-12',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 16,
#                                 'type': 'album',
# ...
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b27361ffafd5e31a37336531cf95',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e0261ffafd5e31a37336531cf95',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000485161ffafd5e31a37336531cf95',
#                                             'width': 64}],
#                                 'name': 'Fanmail',
#                                 'release_date': '1999-02-23',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 17,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:1CvjjpvqVMoyprsf74bpYW'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0TImkz4nPqjegtVSMZnMRq'},
#                                    'href': 'https://api.spotify.com/v1/artists/0TImkz4nPqjegtVSMZnMRq',
#                                    'id': '0TImkz4nPqjegtVSMZnMRq',
#                                    'name': 'TLC',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:0TImkz4nPqjegtVSMZnMRq'}],
#                       'disc_number': 1,
#                       'duration_ms': 214400,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USLF29900479'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/1KGi9sZVMeszgZOWivFpxs'},
#                       'href': 'https://api.spotify.com/v1/tracks/1KGi9sZVMeszgZOWivFpxs',
#                       'id': '1KGi9sZVMeszgZOWivFpxs',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'No Scrubs',
#                       'popularity': 81,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/69daa711bddd8fe7aa9acf17106ca85cf1ccfa14?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#                       'track': True,
#                       'track_number': 5,
#                       'type': 'track',
#                       'uri': 'spotify:track:1KGi9sZVMeszgZOWivFpxs'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2016-09-09T10:44:51Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#                          'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#                          'id': '22htsfsj6ksp4hr6bal4zvboa',
#                          'type': 'user',
#                          'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2gBjLmx6zQnFGQJCAQpRgw'},
#                                              'href': 'https://api.spotify.com/v1/artists/2gBjLmx6zQnFGQJCAQpRgw',
#                                              'id': '2gBjLmx6zQnFGQJCAQpRgw',
#                                              'name': 'Nelly',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:2gBjLmx6zQnFGQJCAQpRgw'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/1kh5XByhI0DDWV7m9kddr0'},
#                                 'href': 'https://api.spotify.com/v1/albums/1kh5XByhI0DDWV7m9kddr0',
#                                 'id': '1kh5XByhI0DDWV7m9kddr0',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273367bb42d6ff622f44303bae5',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02367bb42d6ff622f44303bae5',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851367bb42d6ff622f44303bae5',
#                                             'width': 64}],
#                                 'name': 'Nellyville',
#                                 'release_date': '2002-06-25',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 20,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:1kh5XByhI0DDWV7m9kddr0'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2gBjLmx6zQnFGQJCAQpRgw'},
#                                    'href': 'https://api.spotify.com/v1/artists/2gBjLmx6zQnFGQJCAQpRgw',
#                                    'id': '2gBjLmx6zQnFGQJCAQpRgw',
#                                    'name': 'Nelly',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:2gBjLmx6zQnFGQJCAQpRgw'}],
#                       'disc_number': 1,
#                       'duration_ms': 228240,
#                       'episode': False,
#                       'explicit': True,
#                       'external_ids': {'isrc': 'USUR10200371'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/5FLctoy4mpCxLJ1QPneTOV'},
#                       'href': 'https://api.spotify.com/v1/tracks/5FLctoy4mpCxLJ1QPneTOV',
#                       'id': '5FLctoy4mpCxLJ1QPneTOV',
#                       'is_local': False,
#                       'is_playable': True,
#                       'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/04KTF78FFg8sOHC1BADqbY'},
#                                       'href': 'https://api.spotify.com/v1/tracks/04KTF78FFg8sOHC1BADqbY',
#                                       'id': '04KTF78FFg8sOHC1BADqbY',
#                                       'type': 'track',
#                                       'uri': 'spotify:track:04KTF78FFg8sOHC1BADqbY'},
#                       'name': 'Hot In Herre',
#                       'popularity': 59,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 3,
#                       'type': 'track',
#                       'uri': 'spotify:track:5FLctoy4mpCxLJ1QPneTOV'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2016-09-09T10:44:51Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#                          'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#                          'id': '22htsfsj6ksp4hr6bal4zvboa',
#                          'type': 'user',
#                          'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2NdeV5rLm47xAvogXrYhJX'},
#                                              'href': 'https://api.spotify.com/v1/artists/2NdeV5rLm47xAvogXrYhJX',
#                                              'id': '2NdeV5rLm47xAvogXrYhJX',
#                                              'name': 'Ciara',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:2NdeV5rLm47xAvogXrYhJX'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/71gUhKYZIWmmjqAHlY4Br3'},
#                                 'href': 'https://api.spotify.com/v1/albums/71gUhKYZIWmmjqAHlY4Br3',
#                                 'id': '71gUhKYZIWmmjqAHlY4Br3',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273c1e3659212de0f437bbf395e',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02c1e3659212de0f437bbf395e',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851c1e3659212de0f437bbf395e',
#                                             'width': 64}],
#                                 'name': 'Goodies',
#                                 'release_date': '2004-09-27',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 13,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:71gUhKYZIWmmjqAHlY4Br3'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2NdeV5rLm47xAvogXrYhJX'},
#                                    'href': 'https://api.spotify.com/v1/artists/2NdeV5rLm47xAvogXrYhJX',
#                                    'id': '2NdeV5rLm47xAvogXrYhJX',
#                                    'name': 'Ciara',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:2NdeV5rLm47xAvogXrYhJX'},
#                                   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2wIVse2owClT7go1WT98tk'},
#                                    'href': 'https://api.spotify.com/v1/artists/2wIVse2owClT7go1WT98tk',
#                                    'id': '2wIVse2owClT7go1WT98tk',
#                                    'name': 'Missy Elliott',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:2wIVse2owClT7go1WT98tk'}],
#                       'disc_number': 1,
#                       'duration_ms': 203786,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USLF20400121'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/7uKcScNXuO3MWw6LowBjW1'},
#                       'href': 'https://api.spotify.com/v1/tracks/7uKcScNXuO3MWw6LowBjW1',
#                       'id': '7uKcScNXuO3MWw6LowBjW1',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'One, Two Step (feat. Missy Elliott)',
#                       'popularity': 77,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/ebc79c6e835bd18a744307d51c942a749e3ad2ca?cid=11aeab0ee6e244cea478c7b9ef6d1af0',
#                       'track': True,
#                       'track_number': 2,
#                       'type': 'track',
#                       'uri': 'spotify:track:7uKcScNXuO3MWw6LowBjW1'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2016-09-09T10:44:51Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#                          'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#                          'id': '22htsfsj6ksp4hr6bal4zvboa',
#                          'type': 'user',
#                          'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#                                              'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#                                              'id': '5YGY8feqx7naU7z4HrwZM6',
#                                              'name': 'Miley Cyrus',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/0IuHVgAvbNDJnJepuSZ8Oz'},
#                                 'href': 'https://api.spotify.com/v1/albums/0IuHVgAvbNDJnJepuSZ8Oz',
#                                 'id': '0IuHVgAvbNDJnJepuSZ8Oz',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2734ea6653890e297d53e93e3e0',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e024ea6653890e297d53e93e3e0',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048514ea6653890e297d53e93e3e0',
#                                             'width': 64}],
#                                 'name': 'The Time Of Our Lives (International '
#                                         'Version)',
#                                 'release_date': '2009-01-01',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 8,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:0IuHVgAvbNDJnJepuSZ8Oz'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#                                    'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#                                    'id': '5YGY8feqx7naU7z4HrwZM6',
#                                    'name': 'Miley Cyrus',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#                       'disc_number': 1,
#                       'duration_ms': 202066,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USHR10924519'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/3E7dfMvvCLUddWissuqMwr'},
#                       'href': 'https://api.spotify.com/v1/tracks/3E7dfMvvCLUddWissuqMwr',
#                       'id': '3E7dfMvvCLUddWissuqMwr',
#                       'is_local': False,
#                       'is_playable': True,
#                       'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/5Q0Nhxo0l2bP3pNjpGJwV1'},
#                                       'href': 'https://api.spotify.com/v1/tracks/5Q0Nhxo0l2bP3pNjpGJwV1',
#                                       'id': '5Q0Nhxo0l2bP3pNjpGJwV1',
#                                       'type': 'track',
#                                       'uri': 'spotify:track:5Q0Nhxo0l2bP3pNjpGJwV1'},
#                       'name': 'Party In The U.S.A.',
#                       'popularity': 82,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 2,
#                       'type': 'track',
#                       'uri': 'spotify:track:3E7dfMvvCLUddWissuqMwr'},
#             'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/2Uh5VseH92384vmM5SMUgA/tracks?offset=100&limit=100&market=GB&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 516}

# %% [markdown]
# ### Extracting the songs from the playlist

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']['name']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
get_playlist_tracks("spotify", "2Uh5VseH92384vmM5SMUgA")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/x7/r2pcnk8558z12w_v99lrx7z00000gn/T/ipykernel_51826/2641843286.py in <module>
# ----> 1 get_playlist_tracks("spotify", "2Uh5VseH92384vmM5SMUgA")
#
# /var/folders/x7/r2pcnk8558z12w_v99lrx7z00000gn/T/ipykernel_51826/3634671394.py in get_playlist_tracks(username, playlist_id)
#       1 def get_playlist_tracks(username, playlist_id):
#       2     results = sp.user_playlist_tracks(username,playlist_id,market="GB")
# ----> 3     tracks = results['items']['name']
#       4     while results['next']:
#       5         results = sp.next(results)
#
# TypeError: list indices must be integers or slices, not str

# %%
len(get_playlist_tracks("spotify", "2Uh5VseH92384vmM5SMUgA"))
# Out:
# 516

# %% [markdown]
# ### Extracting the artists from the list

# %% [markdown]
# def function to extract from each track:

# %%
def get_artists_from_track(track):
    return [artist["name"] for artist in track["artists"]]

# %% [markdown]
# def function to get artist from playlist:

# %%
def get_artists_from_playlist(playlist_id):
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    return list(set(artist for subset in [get_artists_from_track(track["track"]) for track in tracks_from_playlist] for artist in subset))

# %%
get_artists_from_playlist("37i9dQZF1EQqZlCxLOykhS")
# Out:
# ['Bon Jovi',
#  'New Edition',
#  'Beastie Boys',
#  'Clean Bandit',
#  'Prince',
#  'John Mellencamp',
#  'Tears For Fears',
#  'Madonna',
#  'Europe',
#  'Journey',
#  'Elton John',
#  'AC/DC',
#  'Matthew Wilder',
#  'Pixies',
#  'Traveling Wilburys',
#  'Belinda Carlisle',
#  'Def Leppard',
#  'Richard Marx',
#  'Genesis',
#  'Rick Astley',
#  'Crowded House',
#  'Quiet Riot',
#  'TOTO',
#  'Michael Jackson',
#  'DeBarge',
#  'The Police',
#  'Joan Jett & The Blackhearts',
#  'Starship',
#  "Guns N' Roses",
#  'N.W.A.',
#  'Hombres G',
#  'Ozzy Osbourne',
#  'Rick James',
#  'a-ha',
#  'Wham!',
#  'Phil Collins',
#  'Red Hot Chili Peppers',
#  'Rick Springfield',
#  'Fleetwood Mac',
#  '38 Special',
#  "Jane's Addiction",
#  'The Human League',
#  'Whitney Houston',
#  'Salt-N-Pepa',
#  'George Strait']
